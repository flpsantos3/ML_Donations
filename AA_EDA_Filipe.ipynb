# %% [markdown]
# # Machine Learning / Aprendizagem Automática
#
# ## Diogo Soares, André Falcão and Sara C. Madeira, 2020/21
#
# # ML Project  - Learning about Donations

# %% [markdown]
# ## Logistics
#
# **Students are encouraged to work in teams of 3 people**.
#
# Projects with smaller teams are allowed, in exceptional cases, but will not have better grades for this reason.
#
# The quality of the project will dictate its grade, not the number of people working.
#
# **The project's solution should be uploaded in Moodle before the end of December, 18th (last day before Christmas holidays).**
#
# Students should **upload a `.zip` file** containing all the files necessary for project evaluation.
#
# **It is mandatory to produce a Jupyter notebook containing code and text/images/tables/etc describing the solution and the results. The notebook is both the solution and the report.**
#
# **Decisions should be fundamented and results should be critically discussed.**

# %% [markdown]
# ## Tools
#
# The team should use [Python 3](https://www.python.org) and [Jupyter Notebook](http://jupyter.org), together with **[Scikit-learn](http://scikit-learn.org/stable/)**, **[Orange3](https://orange.biolab.si)**, or **both**.
#
# **[Orange3](https://orange.biolab.si)** can be used through its **[programmatic version](https://docs.orange.biolab.si/3/data-mining-library/)**, by importing and using its packages, or throught its **workflow version**.
#
# **It is up to the team to decide when to use Scikit-learn, Orange, or both.**
#
# In this context, your Jupyter notebook might have a mix of code, results, text explanations, workflow figures, etc.
#
# In case you use Orange/workflows for some tasks you should also deliver the workflow files and explain the options taken in each widget in your notebook.
#
# **You can use this noteboook and the sections below as template for your work.**

# %% [markdown]
# ## Dataset
#
# The dataset to be analysed is **`Donors_dataset.csv`**, made available together with this project description. This dataset, downloaded from [Kaggle](https://www.kaggle.com), contains selected data from the following dataset: [Donors-Prediction](https://www.kaggle.com/momohmustapha/donorsprediction/).
#
#
# **In this project, your team is supposed to use only tabular data (not Images or Image Metadata) and see how far you can go in predicting donations and understanding the donors. You should use both supervised and unsupervised learning to tackled 2 tasks:**
#
# 1. **Task 1 (Supervised Learning) - Predicting Donation and Donation Type**
# 2. **Task 2 (Unsupervised Learning) - Characterizing Donors**
#
# The **`Donors_dataset.csv`** you should learn from has **19.372 instances** described by **50 data fields** that you might use as **categorical/numerical features**
#
# ### File Descriptions
#
# * **Donors_dataset.csv** - Tabular/text data to be used in the machine learning tasks.
#
#
# ### Data Fields
#
# * **CARD_PROM_12** - number of card promotions sent to the individual by the charitable organization in the past 12 months
# * **CLUSTER_CODE** - one of 54 possible cluster codes, which are unique in terms of socioeconomic status, urbanicity, ethnicity, and other demographic characteristics
# * **CONTROL_NUMBER** - unique identifier of each individual
# * **DONOR_AGE** - age as of last year's mail solicitation
# * **DONOR_GENDER** - actual or inferred gender
# * **FILE_AVG_GIFT** - this variable is identical to LIFETIME_AVG_GIFT_AMT
# * **FILE_CARD_GIFT** - lifetime average donation (in \\$) from the individual in response to all card solicitations from the charitable organization
# * **FREQUENCY_STATUS_97NK** - based on the period of recency (determined by RECENCY_STATUS_96NK), which is the past 12 months for all groups except L and E. L and E are 13–24 months ago and 25–36 months ago, respectively: 1 if one donation in this period, 2 if two donations in this period, 3 if three donations in this period, and 4 if four or more donations in this period.
# * **HOME_OWNER** - H if the individual is a homeowner, U if this information is unknown
# * **INCOME_GROUP** - one of 7 possible income level groups based on a number of demographic characteristics
# * **IN_HOUSE** - 1 if the individual has ever donated to the charitable organization's In House program, 0 if not
# * **LAST_GIFT_AMT** - amount of the most recent donation from the individual to the charitable organization
# * **LIFETIME_AVG_GIFT_AMT** - lifetime average donation (in \\$) from the individual to the charitable organization
# * **LIFETIME_CARD_PROM** - total number of card promotions sent to the individual by the charitable organization
# * **LIFETIME_GIFT_AMOUNT** - total lifetime donation amount (in \\$) from the individual to the charitable organization
# * **LIFETIME_GIFT_COUNT** - total number of donations from the individual to the charitable organization
# * **LIFETIME_GIFT_RANGE** - maximum donation amount from the individual minus minimum donation amount from the individual
# * **LIFETIME_MAX_GIFT_AMT** - maximum donation amount (in \\$) from the individual to the charitable organization
# * **LIFETIME_MIN_GIFT_AMT** - minimum donation amount (in \\$) from the individual to the charitable organization
# * **LIFETIME_PROM** - total number of promotions sent to the individual by the charitable organization
# * **MEDIAN_HOME_VALUE** - median home value (in 100\\$) as determined by other input variables
# * **MEDIAN_HOUSEHOLD_INCOME** - median household income (in 100\\$) as determined by other input variables
# * **MONTHS_SINCE_FIRST_GIFT** - number of months since the first donation from the individual to the charitable organization
# * **MONTHS_SINCE_LAST_GIFT** - number of months since the most recent donation from the individual to the charitable organization
# * **MONTHS_SINCE_LAST_PROM_RESP** - number of months since the individual has responded to a promotion by the charitable organization
# * **MONTHS_SINCE_ORIGIN** - number of months that the individual has been in the charitable organization's database
# * **MOR_HIT_RATE** - total number of known times the donor has responded to a mailed solicitation from a group other than the charitable organization
# * **NUMBER_PROM_12** - number of promotions (card or other) sent to the individual by the charitable organization in the past 12 months
# * **OVERLAY_SOURCE** - the data source against which the individual was matched: M if Metromail, P if Polk, B if both
# * **PCT_ATTRIBUTE1** - percent of residents in the neighborhood in which the individual lives that are males and active military
# * **PCT_ATTRIBUTE2** - percent of residents in the neighborhood in which the individual lives that are males and veterans
# * **PCT_ATTRIBUTE3** - percent of residents in the neighborhood in which the individual lives that are Vietnam veterans
# * **PCT_ATTRIBUTE4** - percent of residents in the neighborhood in which the individual lives that are WWII veterans
# * **PCT_OWNER_OCCUPIED** - percent of owner-occupied housing in the neighborhood in which the individual lives
# * **PEP_STAR** - 1 if individual has ever achieved STAR donor status, 0 if not
# * **PER_CAPITA_INCOME** - per capita income (in \\$) of the neighborhood in which the individual lives
# * **PUBLISHED_PHONE** - 1 if the individual's telephone number is published, 0 if not
# * **RECENCY_STATUS_96NK** - recency status as of two years ago: A if active donor, S if star donor, N if new donor, E if inactive donor, F if first time donor, L if lapsing donor
# * **RECENT_AVG_CARD_GIFT_AMT** - average donation from the individual in response to a card solicitation from the charitable organization since four years ago
# * **RECENT_AVG_GIFT_AMT** - average donation (in \\$) from the individual to the charitable organization since four years ago
# * **RECENT_CARD_RESPONSE_COUNT** - number of times the individual has responded to a card solicitation from the charitable organization since four years ago
# * **RECENT_CARD_RESPONSE_PROP** - proportion of responses to the individual to the number of card solicitations from the charitable organization since four years ago
# * **RECENT_RESPONSE_COUNT** - number of times the individual has responded to a promotion (card or other) from the charitable organization since four years ago
# * **RECENT_RESPONSE_PROP** - proportion of responses to the individual to the number of (card or other) solicitations from the charitable organization since four years ago
# * **RECENT_STAR_STATUS** - 1 if individual has achieved star donor status since four years ago, 0 if not
# * **SES** - one of 5 possible socioeconomic codes classifying the neighborhood in which the individual lives
# * **TARGET_B** - 1 if individual donated in response to last year's 97NK mail solicitation from the charitable organization, 0 if individual did not
# * **TARGET_D** - amount of donation (in \\$) from the individual in response to last year's 97NK mail solicitation from the charitable organization
# * **URBANICITY** - classification of the neighborhood in which the individual lives: U if urban, C if city, S if suburban, T if town, R if rural, ? if missing
# * **WEALTH_RATING** - one of 10 possible wealth rating groups based on a number of demographic characteristics
#
#
# ### Donation TYPE
#
# You are supposed to create a new column/feature named `DONATION_TYPE`, whose values describe ranges of the donation amount (DA) reported in feature `TARGET_D`:
# * `A` - DA >= 50
# * `B` - 20 <= DA < 50
# * `C` - 13 <= DA < 20
# * `D` - 10 <= DA < 13
# * `E` - DA < 10
#
#
# ### **Important Notes on Data Cleaning and Preprocessing**
#
#    1. Data can contain **errors/typos**, whose correction might improve the analysis.
#    2. Some features can contain **many values**, whose grouping in categories (aggregation into bins) might improve the analysis.
#    3. Data can contain **missing values**, that you might decide to fill. You might also decide to eliminate instances/features with high percentages of missing values.
#    4. **Not all features are necessarily important** for the analysis.
#    5. Depending on the analysis, **some features might have to be excluded**.
#    6. Class distribution is an important characteristic of the dataset that should be checked. **Class imbalance** might impair machine learning.
#
# Some potentially useful links:
#
# * Data Cleaning and Preprocessing in Scikit-learn: https://scikit-learn.org/stable/modules/preprocessing.html#
# * Data Cleaning and Preprocessing in Orange: https://docs.biolab.si//3/visual-programming/widgets/data/preprocess.html
# * Dealing with imbalance datasets: https://pypi.org/project/imbalanced-learn/ and https://www.kaggle.com/rafjaa/resampling-strategies-for-imbalanced-datasets#t7

# %% [markdown]
# ## Task 0 (Know your Data) - Exploratory Data Analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## 0.1. Loading Data

# %%
donors = pd.read_csv("Donors_dataset.csv", header=0, na_values="?")

# %%
pd.set_option('display.max_columns', None)
donors
# Out:
#        TARGET_B  TARGET_D  CONTROL_NUMBER  MONTHS_SINCE_ORIGIN  DONOR_AGE  \
# 0             0       NaN               5                  101       87.0
# 1             1      10.0              12                  137       79.0
# 2             0       NaN              37                  113       75.0
# 3             0       NaN              38                   92        NaN
# 4             0       NaN              41                  101       74.0
# ...         ...       ...             ...                  ...        ...
# 19367         0       NaN          191687                   89       66.0
# 19368         0       NaN          191710                  137       77.0
# 19369         0       NaN          191746                   29        NaN
# 19370         0       NaN          191775                  129       78.0
# 19371         1     150.0          191779                   29       70.0
#
#        IN_HOUSE URBANICITY  SES CLUSTER_CODE HOME_OWNER DONOR_GENDER  \
# 0             0        NaN  NaN            .          H            M
# 1             0          R  2.0           45          H            M
# 2             0          S  1.0           11          H            F
# 3             0          U  2.0            4          H            F
# 4             0          R  2.0           49          U            F
# ...         ...        ...  ...          ...        ...          ...
# 19367         1          U  1.0            3          H            F
# 19368         1          C  1.0           24          H            F
# 19369         1          S  1.0           11          U            M
# 19370         1        NaN  NaN            .          U            M
# 19371         0        NaN  NaN            .          U            M
#
#        INCOME_GROUP  PUBLISHED_PHONE OVERLAY_SOURCE  MOR_HIT_RATE  \
# 0               2.0                0              P             0
# 1               7.0                0              P             0
# 2               5.0                0              P             0
# 3               6.0                1              B             0
# 4               2.0                1              B             8
# ...             ...              ...            ...           ...
# 19367           4.0                1              B           241
# 19368           5.0                1              B           240
# 19369           1.0                1              P             0
# 19370           6.0                1              B             0
# 19371           5.0                1              B             2
#
#        WEALTH_RATING  MEDIAN_HOME_VALUE  MEDIAN_HOUSEHOLD_INCOME  \
# 0                NaN                554                      294
# 1                3.0                334                      212
# 2                9.0               2388                      405
# 3                4.0               1688                      153
# 4                5.0                514                      328
# ...              ...                ...                      ...
# 19367            7.0               1224                      411
# 19368            7.0                778                      388
# 19369            NaN                383                      203
# 19370            9.0               1861                      421
# 19371            NaN               1432                      636
#
#        PCT_OWNER_OCCUPIED  PER_CAPITA_INCOME  PCT_ATTRIBUTE1  PCT_ATTRIBUTE2  \
# 0                      76              11855               0               0
# 1                      72              10385               0              41
# 2                      63              30855               0              25
# 3                       3              16342               0              25
# 4                      90              12107               0              33
# ...                   ...                ...             ...             ...
# 19367                  53              17457               1              24
# 19368                  67              18431               3              36
# 19369                  74              11971               0              41
# 19370                  84              22294               0               0
# 19371                  98              35544               0              62
#
#        PCT_ATTRIBUTE3  PCT_ATTRIBUTE4  PEP_STAR  RECENT_STAR_STATUS  \
# 0                   0               0         1                   0
# 1                  21              31         1                   1
# 2                  26              57         1                   1
# 3                  32              42         1                   0
# 4                  36              37         0                   0
# ...               ...             ...       ...                 ...
# 19367              34              41         0                   0
# 19368              28              56         1                   1
# 19369              20              58         0                   0
# 19370               0               0         1                  14
# 19371              13              61         0                   0
#
#       RECENCY_STATUS_96NK  FREQUENCY_STATUS_97NK  RECENT_RESPONSE_PROP  \
# 0                       A                      1                 0.067
# 1                       S                      2                 0.235
# 2                       S                      3                 0.409
# 3                       A                      3                 0.474
# 4                       A                      1                 0.100
# ...                   ...                    ...                   ...
# 19367                   A                      2                 0.154
# 19368                   S                      3                 0.200
# 19369                   N                      1                 0.000
# 19370                   A                      1                 0.053
# 19371                   N                      1                 0.100
#
#        RECENT_AVG_GIFT_AMT  RECENT_CARD_RESPONSE_PROP  \
# 0                    15.00                      0.000
# 1                    15.00                      0.250
# 2                    21.67                      0.545
# 3                    13.44                      0.400
# 4                    17.50                      0.111
# ...                    ...                        ...
# 19367                15.00                      0.167
# 19368                 9.00                      0.200
# 19369                 0.00                      0.000
# 19370                25.00                      0.000
# 19371                25.00                      0.250
#
#        RECENT_AVG_CARD_GIFT_AMT  RECENT_RESPONSE_COUNT  \
# 0                          0.00                      1
# 1                         15.00                      4
# 2                         22.67                      9
# 3                         13.50                      9
# 4                         10.00                      2
# ...                         ...                    ...
# 19367                     15.00                      2
# 19368                     10.00                      4
# 19369                      0.00                      0
# 19370                      0.00                      1
# 19371                     25.00                      1
#
#        RECENT_CARD_RESPONSE_COUNT  MONTHS_SINCE_LAST_PROM_RESP  \
# 0                               0                         26.0
# 1                               2                         11.0
# 2                               6                         14.0
# 3                               4                         11.0
# 4                               1                         18.0
# ...                           ...                          ...
# 19367                           1                         18.0
# 19368                           2                         21.0
# 19369                           0                          NaN
# 19370                           0                         23.0
# 19371                           1                         24.0
#
#        LIFETIME_CARD_PROM  LIFETIME_PROM  LIFETIME_GIFT_AMOUNT  \
# 0                      19             45                 297.0
# 1                      32             90                 368.0
# 2                      44            119                 603.0
# 3                      31             96                 435.0
# 4                      30             83                 106.0
# ...                   ...            ...                   ...
# 19367                  18             50                 103.0
# 19368                  32             76                 164.0
# 19369                   5             14                  15.0
# 19370                  31             99                 440.0
# 19371                   7             18                  25.0
#
#        LIFETIME_GIFT_COUNT  LIFETIME_AVG_GIFT_AMT  LIFETIME_GIFT_RANGE  \
# 0                       35                   8.49                 15.0
# 1                       25                  14.72                 20.0
# 2                       36                  16.75                 23.0
# 3                       37                  11.76                 14.0
# 4                       12                   8.83                 20.0
# ...                    ...                    ...                  ...
# 19367                    6                  17.17                 22.0
# 19368                   21                   7.81                  9.0
# 19369                    1                  15.00                  0.0
# 19370                   24                  18.33                 20.0
# 19371                    1                  25.00                  0.0
#
#        LIFETIME_MAX_GIFT_AMT  LIFETIME_MIN_GIFT_AMT  LAST_GIFT_AMT  \
# 0                       20.0                    5.0           15.0
# 1                       25.0                    5.0           17.0
# 2                       28.0                    5.0           19.0
# 3                       17.0                    3.0           15.0
# 4                       25.0                    5.0           25.0
# ...                      ...                    ...            ...
# 19367                   25.0                    3.0           15.0
# 19368                   10.0                    1.0           10.0
# 19369                   15.0                   15.0           15.0
# 19370                   25.0                    5.0           25.0
# 19371                   25.0                   25.0           25.0
#
#        CARD_PROM_12  NUMBER_PROM_12  MONTHS_SINCE_LAST_GIFT  \
# 0                 5              12                      26
# 1                 7              21                       7
# 2                11              32                       6
# 3                11              33                       6
# 4                 6              19                      18
# ...             ...             ...                     ...
# 19367             6              13                      18
# 19368             6              13                      21
# 19369             3               9                      23
# 19370             7              24                       8
# 19371             4               9                      24
#
#        MONTHS_SINCE_FIRST_GIFT  FILE_AVG_GIFT  FILE_CARD_GIFT
# 0                           92           8.49               7
# 1                          122          14.72              12
# 2                          105          16.75              16
# 3                           92          11.76              12
# 4                           92           8.83               3
# ...                        ...            ...             ...
# 19367                       81          17.17               3
# 19368                      130           7.81              13
# 19369                       23          15.00               0
# 19370                      129          18.33              11
# 19371                       24          25.00               1
#
# [19372 rows x 50 columns]

# %% [markdown]
# ## 0.2. Understanding Data

# %% [markdown]
# In this task you should **understand better the features**, their distribution of values, potential errors, etc and plan/describe what data preprocessing steps should be performed next. Very important also is to check the distribution of values in the target (class distribution).
#
# Here you can find a notebook with some examples of what you can do in **Exploratory Data Analysis**: https://www.kaggle.com/artgor/exploration-of-data-step-by-step/notebook. You can also use Orange widgets for this.

# %%
donors.shape
# Out:
# (19372, 50)

# %% [markdown]
# There are a total of 19372 entries in the dataset and 50(!) features.

# %%
donors.describe()
# Out:
#            TARGET_B     TARGET_D  CONTROL_NUMBER  MONTHS_SINCE_ORIGIN  \
# count  19372.000000  4843.000000    19372.000000         19372.000000
# mean       0.250000    15.624344    96546.225377            73.409973
# std        0.433024    12.445137    55830.643871            41.255574
# min        0.000000     1.000000        5.000000             5.000000
# 25%        0.000000    10.000000    48289.000000            29.000000
# 50%        0.000000    13.000000    96937.000000            65.000000
# 75%        0.250000    20.000000   145429.500000           113.000000
# max        1.000000   200.000000   191779.000000           137.000000
#
#           DONOR_AGE      IN_HOUSE           SES  INCOME_GROUP  \
# count  14577.000000  19372.000000  18918.000000  14980.000000
# mean      58.919051      0.073198      1.903425      3.907543
# std       16.669382      0.260469      0.749215      1.864796
# min        0.000000      0.000000      1.000000      1.000000
# 25%       47.000000      0.000000      1.000000      2.000000
# 50%       60.000000      0.000000      2.000000      4.000000
# 75%       73.000000      0.000000      2.000000      5.000000
# max       87.000000      1.000000      4.000000      7.000000
#
#        PUBLISHED_PHONE  MOR_HIT_RATE  WEALTH_RATING  MEDIAN_HOME_VALUE  \
# count     19372.000000  19372.000000   10562.000000       19372.000000
# mean          0.497729      3.361656       5.005397        1079.871929
# std           0.500008      9.503481       2.815386         960.753448
# min           0.000000      0.000000       0.000000           0.000000
# 25%           0.000000      0.000000       3.000000         518.000000
# 50%           0.000000      0.000000       5.000000         747.000000
# 75%           1.000000      3.000000       7.000000        1227.000000
# max           1.000000    241.000000       9.000000        6000.000000
#
#        MEDIAN_HOUSEHOLD_INCOME  PCT_OWNER_OCCUPIED  PER_CAPITA_INCOME  \
# count             19372.000000        19372.000000       19372.000000
# mean                341.970215           69.698999       15857.334452
# std                 164.207807           21.711019        8710.630390
# min                   0.000000            0.000000           0.000000
# 25%                 232.000000           60.000000       10869.000000
# 50%                 311.000000           76.000000       13816.500000
# 75%                 417.000000           85.000000       18308.250000
# max                1500.000000           99.000000      174523.000000
#
#        PCT_ATTRIBUTE1  PCT_ATTRIBUTE2  PCT_ATTRIBUTE3  PCT_ATTRIBUTE4  \
# count    19372.000000    19372.000000    19372.000000    19372.000000
# mean         1.029011       30.573921       29.603293       32.852467
# std          4.918297       11.421471       15.120360       17.839765
# min          0.000000        0.000000        0.000000        0.000000
# 25%          0.000000       25.000000       20.000000       21.000000
# 50%          0.000000       31.000000       29.000000       32.000000
# 75%          0.000000       37.000000       39.000000       43.000000
# max         97.000000       99.000000       99.000000       99.000000
#
#            PEP_STAR  RECENT_STAR_STATUS  FREQUENCY_STATUS_97NK  \
# count  19372.000000        19372.000000           19372.000000
# mean       0.504439            0.931138               1.983998
# std        0.499993            2.545585               1.099346
# min        0.000000            0.000000               1.000000
# 25%        0.000000            0.000000               1.000000
# 50%        1.000000            0.000000               2.000000
# 75%        1.000000            1.000000               3.000000
# max        1.000000           22.000000               4.000000
#
#        RECENT_RESPONSE_PROP  RECENT_AVG_GIFT_AMT  RECENT_CARD_RESPONSE_PROP  \
# count          19372.000000         19372.000000               19372.000000
# mean               0.190127            15.365396                   0.230808
# std                0.113947            10.167485                   0.186230
# min                0.000000             0.000000                   0.000000
# 25%                0.105000            10.000000                   0.100000
# 50%                0.167000            14.000000                   0.200000
# 75%                0.250000            20.000000                   0.333000
# max                1.000000           260.000000                   1.000000
#
#        RECENT_AVG_CARD_GIFT_AMT  RECENT_RESPONSE_COUNT  \
# count               19372.00000           19372.000000
# mean                   11.68547               3.043103
# std                    10.83412               2.046401
# min                     0.00000               0.000000
# 25%                     5.00000               2.000000
# 50%                    10.14000               3.000000
# 75%                    16.00000               4.000000
# max                   300.00000              16.000000
#
#        RECENT_CARD_RESPONSE_COUNT  MONTHS_SINCE_LAST_PROM_RESP  \
# count                19372.000000                 19126.000000
# mean                     1.730539                    19.038900
# std                      1.535521                     3.415559
# min                      0.000000                   -12.000000
# 25%                      1.000000                    17.000000
# 50%                      1.000000                    18.000000
# 75%                      2.000000                    21.000000
# max                      9.000000                    36.000000
#
#        LIFETIME_CARD_PROM  LIFETIME_PROM  LIFETIME_GIFT_AMOUNT  \
# count        19372.000000   19372.000000          19372.000000
# mean            18.668078      47.570514            104.425716
# std              8.558778      22.950158            105.722460
# min              2.000000       5.000000             15.000000
# 25%             11.000000      28.000000             42.000000
# 50%             18.000000      47.000000             79.000000
# 75%             26.000000      64.000000            132.000000
# max             56.000000     194.000000           3775.000000
#
#        LIFETIME_GIFT_COUNT  LIFETIME_AVG_GIFT_AMT  LIFETIME_GIFT_RANGE  \
# count         19372.000000           19372.000000         19372.000000
# mean              9.979765              12.858338            11.587876
# std               8.688163               8.787758            15.116893
# min               1.000000               1.360000             0.000000
# 25%               4.000000               8.000000             5.000000
# 50%               8.000000              11.200000            10.000000
# 75%              14.000000              15.000000            15.000000
# max              95.000000             450.000000           997.000000
#
#        LIFETIME_MAX_GIFT_AMT  LIFETIME_MIN_GIFT_AMT  LAST_GIFT_AMT  \
# count           19372.000000           19372.000000   19372.000000
# mean               19.208808               7.620932      16.584199
# std                16.101128               7.959786      11.977558
# min                 5.000000               0.000000       0.000000
# 25%                12.000000               3.000000      10.000000
# 50%                16.000000               5.000000      15.000000
# 75%                21.000000              10.000000      20.000000
# max              1000.000000             450.000000     450.000000
#
#        CARD_PROM_12  NUMBER_PROM_12  MONTHS_SINCE_LAST_GIFT  \
# count  19372.000000    19372.000000            19372.000000
# mean       5.367128       12.901869               18.191152
# std        1.264205        4.642072                4.033065
# min        0.000000        2.000000                4.000000
# 25%        5.000000       11.000000               16.000000
# 50%        6.000000       12.000000               18.000000
# 75%        6.000000       13.000000               20.000000
# max       17.000000       64.000000               27.000000
#
#        MONTHS_SINCE_FIRST_GIFT  FILE_AVG_GIFT  FILE_CARD_GIFT
# count             19372.000000   19372.000000    19372.000000
# mean                 69.482088      12.858338        5.273591
# std                  37.568169       8.787758        4.607063
# min                  15.000000       1.360000        0.000000
# 25%                  33.000000       8.000000        2.000000
# 50%                  65.000000      11.200000        4.000000
# 75%                 105.000000      15.000000        8.000000
# max                 260.000000     450.000000       41.000000

# %%
donors['TARGET_D']
# Out:
# 0          NaN
# 1         10.0
# 2          NaN
# 3          NaN
# 4          NaN
#          ...
# 19367      NaN
# 19368      NaN
# 19369      NaN
# 19370      NaN
# 19371    150.0
# Name: TARGET_D, Length: 19372, dtype: float64

# %% [markdown]
# ### Addressing superfluous features

# %% [markdown]
# Looking at the features' descriptions, we can immediately point out some that are meaningless for the problem at hand:
# + `CONTROL_NUMBER`: this is a unique identifier for each donor, it has no impact in the donation.
# + `PCT_ATRIBUTE` 1 to 4: unlike other neighbourhood info on the dataset, these features seem irrelevant to what we want to achieve and only create noise.
# + `FILE_AVG_GIFT` and `LIFETIME_AVG_GIFT_AMT`: this features are identical, according to the dataset info. Worth it to check and confirm.

# %%
donors.nunique()
# Out:
# TARGET_B                           2
# TARGET_D                          70
# CONTROL_NUMBER                 19372
# MONTHS_SINCE_ORIGIN               28
# DONOR_AGE                         80
# IN_HOUSE                           2
# URBANICITY                         5
# SES                                4
# CLUSTER_CODE                      54
# HOME_OWNER                         2
# DONOR_GENDER                       4
# INCOME_GROUP                       7
# PUBLISHED_PHONE                    2
# OVERLAY_SOURCE                     4
# MOR_HIT_RATE                      65
# WEALTH_RATING                     10
# MEDIAN_HOME_VALUE               3130
# MEDIAN_HOUSEHOLD_INCOME          924
# PCT_OWNER_OCCUPIED               100
# PER_CAPITA_INCOME              11418
# PCT_ATTRIBUTE1                    72
# PCT_ATTRIBUTE2                    83
# PCT_ATTRIBUTE3                    89
# PCT_ATTRIBUTE4                   100
# PEP_STAR                           2
# RECENT_STAR_STATUS                23
# RECENCY_STATUS_96NK                6
# FREQUENCY_STATUS_97NK              4
# RECENT_RESPONSE_PROP             115
# RECENT_AVG_GIFT_AMT              814
# RECENT_CARD_RESPONSE_PROP         41
# RECENT_AVG_CARD_GIFT_AMT         484
# RECENT_RESPONSE_COUNT             17
# RECENT_CARD_RESPONSE_COUNT        10
# MONTHS_SINCE_LAST_PROM_RESP       37
# LIFETIME_CARD_PROM                52
# LIFETIME_PROM                    143
# LIFETIME_GIFT_AMOUNT             898
# LIFETIME_GIFT_COUNT               74
# LIFETIME_AVG_GIFT_AMT           1966
# LIFETIME_GIFT_RANGE              226
# LIFETIME_MAX_GIFT_AMT            125
# LIFETIME_MIN_GIFT_AMT             88
# LAST_GIFT_AMT                    106
# CARD_PROM_12                      17
# NUMBER_PROM_12                    50
# MONTHS_SINCE_LAST_GIFT            24
# MONTHS_SINCE_FIRST_GIFT          139
# FILE_AVG_GIFT                   1966
# FILE_CARD_GIFT                    32
# dtype: int64

# %% [markdown]
# `CONTROL_NUMBER` values are all unique so we can drop this column.

# %%
donors = donors.drop(["CONTROL_NUMBER"], axis=1)

# %%
donors["FILE_AVG_GIFT"]
# Out:
# 0         8.49
# 1        14.72
# 2        16.75
# 3        11.76
# 4         8.83
#          ...
# 19367    17.17
# 19368     7.81
# 19369    15.00
# 19370    18.33
# 19371    25.00
# Name: FILE_AVG_GIFT, Length: 19372, dtype: float64

# %%
donors["LIFETIME_AVG_GIFT_AMT"]
# Out:
# 0         8.49
# 1        14.72
# 2        16.75
# 3        11.76
# 4         8.83
#          ...
# 19367    17.17
# 19368     7.81
# 19369    15.00
# 19370    18.33
# 19371    25.00
# Name: LIFETIME_AVG_GIFT_AMT, Length: 19372, dtype: float64

# %%
life_avg = list(set(donors["LIFETIME_AVG_GIFT_AMT"]))
file_avg = list(set(donors["FILE_AVG_GIFT"]))

equal = True
for i in range(len(life_avg)):
    if life_avg[i] != file_avg[i]:
        equal = False
        print("Features are NOT the same!")
        
if equal == True:
    print("Features are exactly the same! Remove one.")
# Out:
# Features are exactly the same! Remove one.

# %% [markdown]
# All the values in `LIFETIME_AVG_GIFT_AMT` and `FILE_AVG_GIFT` are equal! We can safely remove one - in this case, we will remove `FILE_AVG_GIFT`.

# %%
donors = donors.drop(["FILE_AVG_GIFT"], axis=1)

# %%
cols = donors[["TARGET_B", "TARGET_D", "PCT_ATTRIBUTE1", "PCT_ATTRIBUTE2", "PCT_ATTRIBUTE3", "PCT_ATTRIBUTE4"]]
plt.figure(figsize=(16,8))
sns.heatmap(cols.corr(), vmin=-1, vmax=1, cmap="coolwarm", annot=True)
plt.show()

# %%
# Evaluating PCT_ATTRIBUTE for donors and non-donors
sns.boxplot(x="TARGET_B", y="PCT_ATTRIBUTE1", data=donors)
# Out:
# <AxesSubplot:xlabel='TARGET_B', ylabel='PCT_ATTRIBUTE1'>

# %%
# Evaluating PCT_ATTRIBUTE for donors and non-donors
sns.boxplot(x="TARGET_B", y="PCT_ATTRIBUTE2", data=donors)
# Out:
# <AxesSubplot:xlabel='TARGET_B', ylabel='PCT_ATTRIBUTE2'>

# %%
# Evaluating PCT_ATTRIBUTE for donors and non-donors
sns.boxplot(x="TARGET_B", y="PCT_ATTRIBUTE3", data=donors)
# Out:
# <AxesSubplot:xlabel='TARGET_B', ylabel='PCT_ATTRIBUTE3'>

# %%
# Evaluating PCT_ATTRIBUTE for donors and non-donors
sns.boxplot(x="TARGET_B", y="PCT_ATTRIBUTE4", data=donors)
# Out:
# <AxesSubplot:xlabel='TARGET_B', ylabel='PCT_ATTRIBUTE4'>

# %% [markdown]
# The `PCT_ATTRIBUTE` features show practically no correlation with the target features. There doesn't seem to be any difference in these features for donors and non-donors. We can drop them without losing any information.

# %%
donors = donors.drop(["PCT_ATTRIBUTE1", "PCT_ATTRIBUTE2", "PCT_ATTRIBUTE3", "PCT_ATTRIBUTE4"], axis=1)

# %% [markdown]
# ### Addressing missing values

# %%
# Counting the number of NaNs in each column
donors.isnull().sum()
# Out:
# TARGET_B                           0
# TARGET_D                       14529
# MONTHS_SINCE_ORIGIN                0
# DONOR_AGE                       4795
# IN_HOUSE                           0
# URBANICITY                       454
# SES                              454
# CLUSTER_CODE                       0
# HOME_OWNER                         0
# DONOR_GENDER                       0
# INCOME_GROUP                    4392
# PUBLISHED_PHONE                    0
# OVERLAY_SOURCE                     0
# MOR_HIT_RATE                       0
# WEALTH_RATING                   8810
# MEDIAN_HOME_VALUE                  0
# MEDIAN_HOUSEHOLD_INCOME            0
# PCT_OWNER_OCCUPIED                 0
# PER_CAPITA_INCOME                  0
# PEP_STAR                           0
# RECENT_STAR_STATUS                 0
# RECENCY_STATUS_96NK                0
# FREQUENCY_STATUS_97NK              0
# RECENT_RESPONSE_PROP               0
# RECENT_AVG_GIFT_AMT                0
# RECENT_CARD_RESPONSE_PROP          0
# RECENT_AVG_CARD_GIFT_AMT           0
# RECENT_RESPONSE_COUNT              0
# RECENT_CARD_RESPONSE_COUNT         0
# MONTHS_SINCE_LAST_PROM_RESP      246
# LIFETIME_CARD_PROM                 0
# LIFETIME_PROM                      0
# LIFETIME_GIFT_AMOUNT               0
# LIFETIME_GIFT_COUNT                0
# LIFETIME_AVG_GIFT_AMT              0
# LIFETIME_GIFT_RANGE                0
# LIFETIME_MAX_GIFT_AMT              0
# LIFETIME_MIN_GIFT_AMT              0
# LAST_GIFT_AMT                      0
# CARD_PROM_12                       0
# NUMBER_PROM_12                     0
# MONTHS_SINCE_LAST_GIFT             0
# MONTHS_SINCE_FIRST_GIFT            0
# FILE_CARD_GIFT                     0
# dtype: int64

# %% [markdown]
# TARGET_D shows 14529 NA values! We can remove some of these because this feature is directly correlated with TARGET_B:
# + if someone didn't donate then TARGET_B = 0 and, obviously, TARGET_D = 0. Also, if someone has a non-null value for TARGET_D then TARGET_B is 1.
# + For the people where TARGET_B = 1 and TARGET_B is null we can impute the median as it will not affect the distribution of the data.

# %%
activeDonors = donors[donors["TARGET_B"]==1]
activeDonors["TARGET_D"].isnull().sum()
# Out:
# 0

# %% [markdown]
# There are 0 NA values for active donors. This means that all the NA's belong to rows where TARGET_B = 0 and, as such, we can just replace them by 0 in the dataset.

# %%
for i in range(len(donors.index)):
    if donors["TARGET_B"][i] == 0:
        donors["TARGET_D"][i] = 0

donors.isnull().sum()
# Out:
# C:\Users\filip\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# TARGET_B                          0
# TARGET_D                          0
# MONTHS_SINCE_ORIGIN               0
# DONOR_AGE                      4795
# IN_HOUSE                          0
# URBANICITY                      454
# SES                             454
# CLUSTER_CODE                      0
# HOME_OWNER                        0
# DONOR_GENDER                      0
# INCOME_GROUP                   4392
# PUBLISHED_PHONE                   0
# OVERLAY_SOURCE                    0
# MOR_HIT_RATE                      0
# WEALTH_RATING                  8810
# MEDIAN_HOME_VALUE                 0
# MEDIAN_HOUSEHOLD_INCOME           0
# PCT_OWNER_OCCUPIED                0
# PER_CAPITA_INCOME                 0
# PEP_STAR                          0
# RECENT_STAR_STATUS                0
# RECENCY_STATUS_96NK               0
# FREQUENCY_STATUS_97NK             0
# RECENT_RESPONSE_PROP              0
# RECENT_AVG_GIFT_AMT               0
# RECENT_CARD_RESPONSE_PROP         0
# RECENT_AVG_CARD_GIFT_AMT          0
# RECENT_RESPONSE_COUNT             0
# RECENT_CARD_RESPONSE_COUNT        0
# MONTHS_SINCE_LAST_PROM_RESP     246
# LIFETIME_CARD_PROM                0
# LIFETIME_PROM                     0
# LIFETIME_GIFT_AMOUNT              0
# LIFETIME_GIFT_COUNT               0
# LIFETIME_AVG_GIFT_AMT             0
# LIFETIME_GIFT_RANGE               0
# LIFETIME_MAX_GIFT_AMT             0
# LIFETIME_MIN_GIFT_AMT             0
# LAST_GIFT_AMT                     0
# CARD_PROM_12                      0
# NUMBER_PROM_12                    0
# MONTHS_SINCE_LAST_GIFT            0
# MONTHS_SINCE_FIRST_GIFT           0
# FILE_CARD_GIFT                    0
# dtype: int64

# %% [markdown]
# All the NA's from `TARGET_D` are now treated. Looking at the rest of the features, we can see that `WEALTH_RATING`, `INCOME_GROUP`, `SES`, `DONOR_AGE` and `URBANICITY` all have a high number of NA values, with the first three being the most problematic.

# %% [markdown]
# Let's start with DONOR_AGE. We can impute the mean for this variable for every NA. This is an 'easy' fix that does not affect the variable distribution.

# %%
ageMedian = donors["DONOR_AGE"].median()
donors["DONOR_AGE"] = donors["DONOR_AGE"].fillna(ageMedian)
donors["DONOR_AGE"].isnull().sum()
# Out:
# 0

# %%
donors.isnull().sum()
# Out:
# TARGET_B                          0
# TARGET_D                          0
# MONTHS_SINCE_ORIGIN               0
# DONOR_AGE                         0
# IN_HOUSE                          0
# URBANICITY                      454
# SES                             454
# CLUSTER_CODE                      0
# HOME_OWNER                        0
# DONOR_GENDER                      0
# INCOME_GROUP                   4392
# PUBLISHED_PHONE                   0
# OVERLAY_SOURCE                    0
# MOR_HIT_RATE                      0
# WEALTH_RATING                  8810
# MEDIAN_HOME_VALUE                 0
# MEDIAN_HOUSEHOLD_INCOME           0
# PCT_OWNER_OCCUPIED                0
# PER_CAPITA_INCOME                 0
# PEP_STAR                          0
# RECENT_STAR_STATUS                0
# RECENCY_STATUS_96NK               0
# FREQUENCY_STATUS_97NK             0
# RECENT_RESPONSE_PROP              0
# RECENT_AVG_GIFT_AMT               0
# RECENT_CARD_RESPONSE_PROP         0
# RECENT_AVG_CARD_GIFT_AMT          0
# RECENT_RESPONSE_COUNT             0
# RECENT_CARD_RESPONSE_COUNT        0
# MONTHS_SINCE_LAST_PROM_RESP     246
# LIFETIME_CARD_PROM                0
# LIFETIME_PROM                     0
# LIFETIME_GIFT_AMOUNT              0
# LIFETIME_GIFT_COUNT               0
# LIFETIME_AVG_GIFT_AMT             0
# LIFETIME_GIFT_RANGE               0
# LIFETIME_MAX_GIFT_AMT             0
# LIFETIME_MIN_GIFT_AMT             0
# LAST_GIFT_AMT                     0
# CARD_PROM_12                      0
# NUMBER_PROM_12                    0
# MONTHS_SINCE_LAST_GIFT            0
# MONTHS_SINCE_FIRST_GIFT           0
# FILE_CARD_GIFT                    0
# dtype: int64

# %% [markdown]
# Next we take a look at `INCOME_GROUP` and `WEALTH_RATING`.

# %%
sns.countplot(x=donors['INCOME_GROUP'])
plt.show()

# %%
sns.countplot(x=donors['WEALTH_RATING'])
plt.show()

# %% [markdown]
# These features are a lot more complicated. As they are categorical values, we could, for example, impute the mode to all missing values. However, as the number of missing values are too high, this would severely impact the dataset and skew the ratings towards the most frequent rating. We also can't just remove the rows with NA values because that would cut almost half of the dataset.

# %% [markdown]
# A possible solution would be to evaluate if these two features are needed. There could be features that show the same type of information as these two. In this case, we are looking at features that convey economic information about the donors.

# %% [markdown]
# Looking at the dataset, that are other features with economic information: `PER_CAPITA_INCOME`, `MEDIAN_HOUSEHOLD_INCOME` and `SES`. It can be interesting to look at the correlation between `WEALTH_RATING` and `INCOME_GROUP` and these features.

# %%
donors.corrwith(donors["WEALTH_RATING"]).sort_values(ascending=False).head()
# Out:
# WEALTH_RATING              1.000000
# MEDIAN_HOUSEHOLD_INCOME    0.603792
# PER_CAPITA_INCOME          0.521337
# INCOME_GROUP               0.419194
# MEDIAN_HOME_VALUE          0.390796
# dtype: float64

# %%
donors.corrwith(donors["INCOME_GROUP"]).sort_values(ascending=False).head()
# Out:
# INCOME_GROUP               1.000000
# MEDIAN_HOUSEHOLD_INCOME    0.428270
# WEALTH_RATING              0.419194
# PER_CAPITA_INCOME          0.354530
# MEDIAN_HOME_VALUE          0.323530
# dtype: float64

# %%
sns.boxplot(x = 'WEALTH_RATING', y = 'PER_CAPITA_INCOME', data = donors)
# Out:
# <AxesSubplot:xlabel='WEALTH_RATING', ylabel='PER_CAPITA_INCOME'>

# %%
sns.boxplot(x = 'WEALTH_RATING', y = 'MEDIAN_HOUSEHOLD_INCOME', data = donors)
# Out:
# <AxesSubplot:xlabel='WEALTH_RATING', ylabel='MEDIAN_HOUSEHOLD_INCOME'>

# %% [markdown]
# `PER_CAPITA_INCOME` and `MEDIAN_HOUSEHOLD_INCOME`seem to display the same information as `WEALTH_RATING`.

# %%
sns.boxplot(x = 'INCOME_GROUP', y = 'PER_CAPITA_INCOME', data = donors)
# Out:
# <AxesSubplot:xlabel='INCOME_GROUP', ylabel='PER_CAPITA_INCOME'>

# %%
sns.boxplot(x = 'INCOME_GROUP', y = 'MEDIAN_HOUSEHOLD_INCOME', data = donors)
# Out:
# <AxesSubplot:xlabel='INCOME_GROUP', ylabel='MEDIAN_HOUSEHOLD_INCOME'>

# %% [markdown]
# The same can be observed when we look at `INCOME_GROUP`. This means we can remove `WEALTH_RATING` and `INCOME_GROUP` from the dataset and still keep the information that these two features convey.

# %%
donors = donors.drop(["INCOME_GROUP", "WEALTH_RATING"], axis=1)

# %% [markdown]
# Now the last NA values are in `MONTHS_SINCE_LAST_PROM_RESP`, `URBANICITY` and `SES`. These are a very small number values when compared with the other problematic features and with the total number of observations in the dataset. If we remove them we won't be losing that much information.

# %%
colsNA = ["MONTHS_SINCE_LAST_PROM_RESP", "SES", "URBANICITY"]
donors = donors.dropna(how='any', subset=colsNA)

# %%
donors.isnull().sum()
# Out:
# TARGET_B                       0
# TARGET_D                       0
# MONTHS_SINCE_ORIGIN            0
# DONOR_AGE                      0
# IN_HOUSE                       0
# URBANICITY                     0
# SES                            0
# CLUSTER_CODE                   0
# HOME_OWNER                     0
# DONOR_GENDER                   0
# PUBLISHED_PHONE                0
# OVERLAY_SOURCE                 0
# MOR_HIT_RATE                   0
# MEDIAN_HOME_VALUE              0
# MEDIAN_HOUSEHOLD_INCOME        0
# PCT_OWNER_OCCUPIED             0
# PER_CAPITA_INCOME              0
# PEP_STAR                       0
# RECENT_STAR_STATUS             0
# RECENCY_STATUS_96NK            0
# FREQUENCY_STATUS_97NK          0
# RECENT_RESPONSE_PROP           0
# RECENT_AVG_GIFT_AMT            0
# RECENT_CARD_RESPONSE_PROP      0
# RECENT_AVG_CARD_GIFT_AMT       0
# RECENT_RESPONSE_COUNT          0
# RECENT_CARD_RESPONSE_COUNT     0
# MONTHS_SINCE_LAST_PROM_RESP    0
# LIFETIME_CARD_PROM             0
# LIFETIME_PROM                  0
# LIFETIME_GIFT_AMOUNT           0
# LIFETIME_GIFT_COUNT            0
# LIFETIME_AVG_GIFT_AMT          0
# LIFETIME_GIFT_RANGE            0
# LIFETIME_MAX_GIFT_AMT          0
# LIFETIME_MIN_GIFT_AMT          0
# LAST_GIFT_AMT                  0
# CARD_PROM_12                   0
# NUMBER_PROM_12                 0
# MONTHS_SINCE_LAST_GIFT         0
# MONTHS_SINCE_FIRST_GIFT        0
# FILE_CARD_GIFT                 0
# dtype: int64

# %%
donors.reset_index(inplace=True, drop=True)

# %% [markdown]
# ### Adding DONATION_TYPE to the dataset

# %% [markdown]
# Creating a new column/feature named `DONATION_TYPE`, whose values describe ranges of the donation amount (DA) reported in feature `TARGET_D`:
# * `A` - DA >= 50
# * `B` - 20 <= DA < 50
# * `C` - 13 <= DA < 20
# * `D` - 10 <= DA < 13
# * `E` - DA < 10

# %%
# create a list for our conditions
conditions = [
    (donors['TARGET_D']  >= 50),
    (donors['TARGET_D'] < 50) & (donors['TARGET_D']  >= 20),
    (donors['TARGET_D'] < 20) & (donors['TARGET_D']  >= 13),
    (donors['TARGET_D'] < 13) & (donors['TARGET_D']  >= 10),
    (donors['TARGET_D'] < 10) & (donors['TARGET_D'] > 0)
    ]

# create a list of the values we want to assign for each condition
values = ['A', 'B', 'C', 'D', 'E']

# create a new column and use np.select to assign values to it using our lists as arguments
donors['DONATION_TYPE'] = np.select(conditions, values)

# %%
donors['DONATION_TYPE']
# Out:
# 0        D
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 18675    0
# 18676    0
# 18677    0
# 18678    0
# 18679    0
# Name: DONATION_TYPE, Length: 18680, dtype: object

# %% [markdown]
# ### Addressing Data Types

# %%
donors
# Out:
#        TARGET_B  TARGET_D  MONTHS_SINCE_ORIGIN  DONOR_AGE  IN_HOUSE  \
# 0             1      10.0                  137       79.0         0
# 1             0       0.0                  113       75.0         0
# 2             0       0.0                   92       60.0         0
# 3             0       0.0                  101       74.0         0
# 4             0       0.0                  101       63.0         0
# ...         ...       ...                  ...        ...       ...
# 18675         0       0.0                  137       84.0         0
# 18676         0       0.0                  137       64.0         1
# 18677         0       0.0                  137       85.0         1
# 18678         0       0.0                   89       66.0         1
# 18679         0       0.0                  137       77.0         1
#
#       URBANICITY  SES CLUSTER_CODE HOME_OWNER DONOR_GENDER  PUBLISHED_PHONE  \
# 0              R  2.0           45          H            M                0
# 1              S  1.0           11          H            F                0
# 2              U  2.0            4          H            F                1
# 3              R  2.0           49          U            F                1
# 4              U  3.0            8          U            M                0
# ...          ...  ...          ...        ...          ...              ...
# 18675          C  3.0           31          U            F                0
# 18676          C  1.0           23          U            F                1
# 18677          T  2.0           40          U            M                1
# 18678          U  1.0            3          H            F                1
# 18679          C  1.0           24          H            F                1
#
#       OVERLAY_SOURCE  MOR_HIT_RATE  MEDIAN_HOME_VALUE  \
# 0                  P             0                334
# 1                  P             0               2388
# 2                  B             0               1688
# 3                  B             8                514
# 4                  P             0                452
# ...              ...           ...                ...
# 18675              B           241                366
# 18676              B           240               2152
# 18677              B           240                715
# 18678              B           241               1224
# 18679              B           240                778
#
#        MEDIAN_HOUSEHOLD_INCOME  PCT_OWNER_OCCUPIED  PER_CAPITA_INCOME  \
# 0                          212                  72              10385
# 1                          405                  63              30855
# 2                          153                   3              16342
# 3                          328                  90              12107
# 4                          182                  51               6851
# ...                        ...                 ...                ...
# 18675                      104                  15               8843
# 18676                      389                  29              28753
# 18677                      399                  89              14796
# 18678                      411                  53              17457
# 18679                      388                  67              18431
#
#        PEP_STAR  RECENT_STAR_STATUS RECENCY_STATUS_96NK  \
# 0             1                   1                   S
# 1             1                   1                   S
# 2             1                   0                   A
# 3             0                   0                   A
# 4             0                   0                   A
# ...         ...                 ...                 ...
# 18675         0                   0                   A
# 18676         1                   1                   S
# 18677         1                   1                   S
# 18678         0                   0                   A
# 18679         1                   1                   S
#
#        FREQUENCY_STATUS_97NK  RECENT_RESPONSE_PROP  RECENT_AVG_GIFT_AMT  \
# 0                          2                 0.235                15.00
# 1                          3                 0.409                21.67
# 2                          3                 0.474                13.44
# 3                          1                 0.100                17.50
# 4                          4                 0.200                 8.33
# ...                      ...                   ...                  ...
# 18675                      4                 0.313                 6.60
# 18676                      2                 0.231                29.00
# 18677                      3                 0.222                 5.00
# 18678                      2                 0.154                15.00
# 18679                      3                 0.200                 9.00
#
#        RECENT_CARD_RESPONSE_PROP  RECENT_AVG_CARD_GIFT_AMT  \
# 0                          0.250                     15.00
# 1                          0.545                     22.67
# 2                          0.400                     13.50
# 3                          0.111                     10.00
# 4                          0.125                     10.00
# ...                          ...                       ...
# 18675                      0.375                      6.67
# 18676                      0.111                     36.00
# 18677                      0.125                      5.00
# 18678                      0.167                     15.00
# 18679                      0.200                     10.00
#
#        RECENT_RESPONSE_COUNT  RECENT_CARD_RESPONSE_COUNT  \
# 0                          4                           2
# 1                          9                           6
# 2                          9                           4
# 3                          2                           1
# 4                          3                           1
# ...                      ...                         ...
# 18675                      5                           3
# 18676                      3                           1
# 18677                      4                           1
# 18678                      2                           1
# 18679                      4                           2
#
#        MONTHS_SINCE_LAST_PROM_RESP  LIFETIME_CARD_PROM  LIFETIME_PROM  \
# 0                             11.0                  32             90
# 1                             14.0                  44            119
# 2                             11.0                  31             96
# 3                             18.0                  30             83
# 4                             19.0                  22             59
# ...                            ...                 ...            ...
# 18675                         17.0                  29             68
# 18676                         16.0                  29             65
# 18677                         15.0                  31             72
# 18678                         18.0                  18             50
# 18679                         21.0                  32             76
#
#        LIFETIME_GIFT_AMOUNT  LIFETIME_GIFT_COUNT  LIFETIME_AVG_GIFT_AMT  \
# 0                     368.0                   25                  14.72
# 1                     603.0                   36                  16.75
# 2                     435.0                   37                  11.76
# 3                     106.0                   12                   8.83
# 4                     128.0                   22                   5.82
# ...                     ...                  ...                    ...
# 18675                  76.0                   11                   6.91
# 18676                 231.0                   14                  16.50
# 18677                 101.0                   19                   5.32
# 18678                 103.0                    6                  17.17
# 18679                 164.0                   21                   7.81
#
#        LIFETIME_GIFT_RANGE  LIFETIME_MAX_GIFT_AMT  LIFETIME_MIN_GIFT_AMT  \
# 0                     20.0                   25.0                    5.0
# 1                     23.0                   28.0                    5.0
# 2                     14.0                   17.0                    3.0
# 3                     20.0                   25.0                    5.0
# 4                      7.0                   10.0                    3.0
# ...                    ...                    ...                    ...
# 18675                  7.0                   10.0                    3.0
# 18676                 31.0                   36.0                    5.0
# 18677                  7.0                   10.0                    3.0
# 18678                 22.0                   25.0                    3.0
# 18679                  9.0                   10.0                    1.0
#
#        LAST_GIFT_AMT  CARD_PROM_12  NUMBER_PROM_12  MONTHS_SINCE_LAST_GIFT  \
# 0               17.0             7              21                       7
# 1               19.0            11              32                       6
# 2               15.0            11              33                       6
# 3               25.0             6              19                      18
# 4               10.0             9              20                      19
# ...              ...           ...             ...                     ...
# 18675            5.0             6              15                      17
# 18676           25.0             5               9                      16
# 18677            5.0             5              12                      15
# 18678           15.0             6              13                      18
# 18679           10.0             6              13                      21
#
#        MONTHS_SINCE_FIRST_GIFT  FILE_CARD_GIFT DONATION_TYPE
# 0                          122              12             D
# 1                          105              16             0
# 2                           92              12             0
# 3                           92               3             0
# 4                           91               6             0
# ...                        ...             ...           ...
# 18675                      122               7             0
# 18676                      121               7             0
# 18677                      126              13             0
# 18678                       81               3             0
# 18679                      130              13             0
#
# [18680 rows x 43 columns]

# %%
donors.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18680 entries, 0 to 18679
# Data columns (total 43 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   TARGET_B                     18680 non-null  int64
#  1   TARGET_D                     18680 non-null  float64
#  2   MONTHS_SINCE_ORIGIN          18680 non-null  int64
#  3   DONOR_AGE                    18680 non-null  float64
#  4   IN_HOUSE                     18680 non-null  int64
#  5   URBANICITY                   18680 non-null  object
#  6   SES                          18680 non-null  float64
#  7   CLUSTER_CODE                 18680 non-null  object
#  8   HOME_OWNER                   18680 non-null  object
#  9   DONOR_GENDER                 18680 non-null  object
#  10  PUBLISHED_PHONE              18680 non-null  int64
#  11  OVERLAY_SOURCE               18680 non-null  object
#  12  MOR_HIT_RATE                 18680 non-null  int64
#  13  MEDIAN_HOME_VALUE            18680 non-null  int64
#  14  MEDIAN_HOUSEHOLD_INCOME      18680 non-null  int64
#  15  PCT_OWNER_OCCUPIED           18680 non-null  int64
#  16  PER_CAPITA_INCOME            18680 non-null  int64
#  17  PEP_STAR                     18680 non-null  int64
#  18  RECENT_STAR_STATUS           18680 non-null  int64
#  19  RECENCY_STATUS_96NK          18680 non-null  object
#  20  FREQUENCY_STATUS_97NK        18680 non-null  int64
#  21  RECENT_RESPONSE_PROP         18680 non-null  float64
#  22  RECENT_AVG_GIFT_AMT          18680 non-null  float64
#  23  RECENT_CARD_RESPONSE_PROP    18680 non-null  float64
#  24  RECENT_AVG_CARD_GIFT_AMT     18680 non-null  float64
#  25  RECENT_RESPONSE_COUNT        18680 non-null  int64
#  26  RECENT_CARD_RESPONSE_COUNT   18680 non-null  int64
#  27  MONTHS_SINCE_LAST_PROM_RESP  18680 non-null  float64
#  28  LIFETIME_CARD_PROM           18680 non-null  int64
#  29  LIFETIME_PROM                18680 non-null  int64
#  30  LIFETIME_GIFT_AMOUNT         18680 non-null  float64
#  31  LIFETIME_GIFT_COUNT          18680 non-null  int64
#  32  LIFETIME_AVG_GIFT_AMT        18680 non-null  float64
#  33  LIFETIME_GIFT_RANGE          18680 non-null  float64
#  34  LIFETIME_MAX_GIFT_AMT        18680 non-null  float64
#  35  LIFETIME_MIN_GIFT_AMT        18680 non-null  float64
#  36  LAST_GIFT_AMT                18680 non-null  float64
#  37  CARD_PROM_12                 18680 non-null  int64
#  38  NUMBER_PROM_12               18680 non-null  int64
#  39  MONTHS_SINCE_LAST_GIFT       18680 non-null  int64
#  40  MONTHS_SINCE_FIRST_GIFT      18680 non-null  int64
#  41  FILE_CARD_GIFT               18680 non-null  int64
#  42  DONATION_TYPE                18680 non-null  object
# dtypes: float64(14), int64(22), object(7)
# memory usage: 6.1+ MB

# %% [markdown]
# We can identify some problems with the datatypes :
# + `TARGET_B`, `IN_HOUSE`, `PUBLISHED_PHONE`, `PEP_STAR`, `RECENT_STAR_STATUS`  are objects, not ints.
# + `DONOR_AGE` and `MONTHS_SINCE_LAST_PROM_RESP` should be an int and not a float.
# + `SES` and `INCOME_GROUP` are categories and should be an object (not a float).
#
# We can also convert all object types to category.

# %%
# float to int
toInt = ['DONOR_AGE', 'MONTHS_SINCE_LAST_PROM_RESP', 'SES', 'INCOME_GROUP']
for col in donors.columns:
    if col in toInt:
        donors[col] = donors[col].astype(int)

# int to category
toCat = ["SES", "INCOME_GROUP", "TARGET_B", "IN_HOUSE", "PUBLISHED_PHONE", "PEP_STAR", "RECENT_STAR_STATUS"]
for col in donors.columns:
    if col in toCat:
        donors[col] = pd.Categorical(donors[col])
        
# object to category
objtoCat = ["URBANICITY", "CLUSTER_CODE", "HOME_OWNER", "DONOR_GENDER", "OVERLAY_SOURCE", "RECENCY_STATUS_96NK", "DONATION_TYPE"]
for col in donors.columns:
    if col in objtoCat:
        donors[col] = pd.Categorical(donors[col])

# %%
donors.dtypes
# Out:
# TARGET_B                       category
# TARGET_D                        float64
# MONTHS_SINCE_ORIGIN               int64
# DONOR_AGE                         int32
# IN_HOUSE                       category
# URBANICITY                     category
# SES                            category
# CLUSTER_CODE                   category
# HOME_OWNER                     category
# DONOR_GENDER                   category
# PUBLISHED_PHONE                category
# OVERLAY_SOURCE                 category
# MOR_HIT_RATE                      int64
# MEDIAN_HOME_VALUE                 int64
# MEDIAN_HOUSEHOLD_INCOME           int64
# PCT_OWNER_OCCUPIED                int64
# PER_CAPITA_INCOME                 int64
# PEP_STAR                       category
# RECENT_STAR_STATUS             category
# RECENCY_STATUS_96NK            category
# FREQUENCY_STATUS_97NK             int64
# RECENT_RESPONSE_PROP            float64
# RECENT_AVG_GIFT_AMT             float64
# RECENT_CARD_RESPONSE_PROP       float64
# RECENT_AVG_CARD_GIFT_AMT        float64
# RECENT_RESPONSE_COUNT             int64
# RECENT_CARD_RESPONSE_COUNT        int64
# MONTHS_SINCE_LAST_PROM_RESP       int32
# LIFETIME_CARD_PROM                int64
# LIFETIME_PROM                     int64
# LIFETIME_GIFT_AMOUNT            float64
# LIFETIME_GIFT_COUNT               int64
# LIFETIME_AVG_GIFT_AMT           float64
# LIFETIME_GIFT_RANGE             float64
# LIFETIME_MAX_GIFT_AMT           float64
# LIFETIME_MIN_GIFT_AMT           float64
# LAST_GIFT_AMT                   float64
# CARD_PROM_12                      int64
# NUMBER_PROM_12                    int64
# MONTHS_SINCE_LAST_GIFT            int64
# MONTHS_SINCE_FIRST_GIFT           int64
# FILE_CARD_GIFT                    int64
# DONATION_TYPE                  category
# dtype: object

# %%
donors
# Out:
#       TARGET_B  TARGET_D  MONTHS_SINCE_ORIGIN  DONOR_AGE IN_HOUSE URBANICITY  \
# 0            1      10.0                  137         79        0          R
# 1            0       0.0                  113         75        0          S
# 2            0       0.0                   92         60        0          U
# 3            0       0.0                  101         74        0          R
# 4            0       0.0                  101         63        0          U
# ...        ...       ...                  ...        ...      ...        ...
# 18675        0       0.0                  137         84        0          C
# 18676        0       0.0                  137         64        1          C
# 18677        0       0.0                  137         85        1          T
# 18678        0       0.0                   89         66        1          U
# 18679        0       0.0                  137         77        1          C
#
#       SES CLUSTER_CODE HOME_OWNER DONOR_GENDER PUBLISHED_PHONE OVERLAY_SOURCE  \
# 0       2           45          H            M               0              P
# 1       1           11          H            F               0              P
# 2       2            4          H            F               1              B
# 3       2           49          U            F               1              B
# 4       3            8          U            M               0              P
# ...    ..          ...        ...          ...             ...            ...
# 18675   3           31          U            F               0              B
# 18676   1           23          U            F               1              B
# 18677   2           40          U            M               1              B
# 18678   1            3          H            F               1              B
# 18679   1           24          H            F               1              B
#
#        MOR_HIT_RATE  MEDIAN_HOME_VALUE  MEDIAN_HOUSEHOLD_INCOME  \
# 0                 0                334                      212
# 1                 0               2388                      405
# 2                 0               1688                      153
# 3                 8                514                      328
# 4                 0                452                      182
# ...             ...                ...                      ...
# 18675           241                366                      104
# 18676           240               2152                      389
# 18677           240                715                      399
# 18678           241               1224                      411
# 18679           240                778                      388
#
#        PCT_OWNER_OCCUPIED  PER_CAPITA_INCOME PEP_STAR RECENT_STAR_STATUS  \
# 0                      72              10385        1                  1
# 1                      63              30855        1                  1
# 2                       3              16342        1                  0
# 3                      90              12107        0                  0
# 4                      51               6851        0                  0
# ...                   ...                ...      ...                ...
# 18675                  15               8843        0                  0
# 18676                  29              28753        1                  1
# 18677                  89              14796        1                  1
# 18678                  53              17457        0                  0
# 18679                  67              18431        1                  1
#
#       RECENCY_STATUS_96NK  FREQUENCY_STATUS_97NK  RECENT_RESPONSE_PROP  \
# 0                       S                      2                 0.235
# 1                       S                      3                 0.409
# 2                       A                      3                 0.474
# 3                       A                      1                 0.100
# 4                       A                      4                 0.200
# ...                   ...                    ...                   ...
# 18675                   A                      4                 0.313
# 18676                   S                      2                 0.231
# 18677                   S                      3                 0.222
# 18678                   A                      2                 0.154
# 18679                   S                      3                 0.200
#
#        RECENT_AVG_GIFT_AMT  RECENT_CARD_RESPONSE_PROP  \
# 0                    15.00                      0.250
# 1                    21.67                      0.545
# 2                    13.44                      0.400
# 3                    17.50                      0.111
# 4                     8.33                      0.125
# ...                    ...                        ...
# 18675                 6.60                      0.375
# 18676                29.00                      0.111
# 18677                 5.00                      0.125
# 18678                15.00                      0.167
# 18679                 9.00                      0.200
#
#        RECENT_AVG_CARD_GIFT_AMT  RECENT_RESPONSE_COUNT  \
# 0                         15.00                      4
# 1                         22.67                      9
# 2                         13.50                      9
# 3                         10.00                      2
# 4                         10.00                      3
# ...                         ...                    ...
# 18675                      6.67                      5
# 18676                     36.00                      3
# 18677                      5.00                      4
# 18678                     15.00                      2
# 18679                     10.00                      4
#
#        RECENT_CARD_RESPONSE_COUNT  MONTHS_SINCE_LAST_PROM_RESP  \
# 0                               2                           11
# 1                               6                           14
# 2                               4                           11
# 3                               1                           18
# 4                               1                           19
# ...                           ...                          ...
# 18675                           3                           17
# 18676                           1                           16
# 18677                           1                           15
# 18678                           1                           18
# 18679                           2                           21
#
#        LIFETIME_CARD_PROM  LIFETIME_PROM  LIFETIME_GIFT_AMOUNT  \
# 0                      32             90                 368.0
# 1                      44            119                 603.0
# 2                      31             96                 435.0
# 3                      30             83                 106.0
# 4                      22             59                 128.0
# ...                   ...            ...                   ...
# 18675                  29             68                  76.0
# 18676                  29             65                 231.0
# 18677                  31             72                 101.0
# 18678                  18             50                 103.0
# 18679                  32             76                 164.0
#
#        LIFETIME_GIFT_COUNT  LIFETIME_AVG_GIFT_AMT  LIFETIME_GIFT_RANGE  \
# 0                       25                  14.72                 20.0
# 1                       36                  16.75                 23.0
# 2                       37                  11.76                 14.0
# 3                       12                   8.83                 20.0
# 4                       22                   5.82                  7.0
# ...                    ...                    ...                  ...
# 18675                   11                   6.91                  7.0
# 18676                   14                  16.50                 31.0
# 18677                   19                   5.32                  7.0
# 18678                    6                  17.17                 22.0
# 18679                   21                   7.81                  9.0
#
#        LIFETIME_MAX_GIFT_AMT  LIFETIME_MIN_GIFT_AMT  LAST_GIFT_AMT  \
# 0                       25.0                    5.0           17.0
# 1                       28.0                    5.0           19.0
# 2                       17.0                    3.0           15.0
# 3                       25.0                    5.0           25.0
# 4                       10.0                    3.0           10.0
# ...                      ...                    ...            ...
# 18675                   10.0                    3.0            5.0
# 18676                   36.0                    5.0           25.0
# 18677                   10.0                    3.0            5.0
# 18678                   25.0                    3.0           15.0
# 18679                   10.0                    1.0           10.0
#
#        CARD_PROM_12  NUMBER_PROM_12  MONTHS_SINCE_LAST_GIFT  \
# 0                 7              21                       7
# 1                11              32                       6
# 2                11              33                       6
# 3                 6              19                      18
# 4                 9              20                      19
# ...             ...             ...                     ...
# 18675             6              15                      17
# 18676             5               9                      16
# 18677             5              12                      15
# 18678             6              13                      18
# 18679             6              13                      21
#
#        MONTHS_SINCE_FIRST_GIFT  FILE_CARD_GIFT DONATION_TYPE
# 0                          122              12             D
# 1                          105              16             0
# 2                           92              12             0
# 3                           92               3             0
# 4                           91               6             0
# ...                        ...             ...           ...
# 18675                      122               7             0
# 18676                      121               7             0
# 18677                      126              13             0
# 18678                       81               3             0
# 18679                      130              13             0
#
# [18680 rows x 43 columns]

# %% [markdown]
# ### EDA - correlation, group imbalance

# %%
donors.corr()
# Out:
#                              TARGET_D  MONTHS_SINCE_ORIGIN  DONOR_AGE  \
# TARGET_D                     1.000000             0.000207   0.005254
# MONTHS_SINCE_ORIGIN          0.000207             1.000000   0.201746
# DONOR_AGE                    0.005254             0.201746   1.000000
# MOR_HIT_RATE                 0.010374             0.081492   0.098522
# MEDIAN_HOME_VALUE            0.086208            -0.047224  -0.001215
# MEDIAN_HOUSEHOLD_INCOME      0.070328            -0.036137  -0.057405
# PCT_OWNER_OCCUPIED           0.008458             0.036576  -0.018317
# PER_CAPITA_INCOME            0.081913            -0.025415   0.006141
# FREQUENCY_STATUS_97NK       -0.026535             0.057012   0.040411
# RECENT_RESPONSE_PROP        -0.025106            -0.111962   0.020803
# RECENT_AVG_GIFT_AMT          0.158420            -0.088864  -0.036175
# RECENT_CARD_RESPONSE_PROP   -0.007350            -0.204587  -0.020718
# RECENT_AVG_CARD_GIFT_AMT     0.113677            -0.106095  -0.024047
# RECENT_RESPONSE_COUNT       -0.022653             0.171037   0.052733
# RECENT_CARD_RESPONSE_COUNT  -0.004611             0.087182   0.025876
# MONTHS_SINCE_LAST_PROM_RESP -0.003884             0.048191  -0.022459
# LIFETIME_CARD_PROM           0.012447             0.912970   0.182720
# LIFETIME_PROM                0.028323             0.864536   0.185501
# LIFETIME_GIFT_AMOUNT         0.108921             0.517699   0.117053
# LIFETIME_GIFT_COUNT         -0.011126             0.717176   0.170892
# LIFETIME_AVG_GIFT_AMT        0.155431            -0.281578  -0.066350
# LIFETIME_GIFT_RANGE          0.114607             0.212928   0.028041
# LIFETIME_MAX_GIFT_AMT        0.145331            -0.017875  -0.019377
# LIFETIME_MIN_GIFT_AMT        0.075000            -0.460319  -0.096081
# LAST_GIFT_AMT                0.172161            -0.107102  -0.041094
# CARD_PROM_12                 0.034278             0.125605   0.037407
# NUMBER_PROM_12               0.056681             0.143328   0.075436
# MONTHS_SINCE_LAST_GIFT      -0.027665            -0.021839  -0.067942
# MONTHS_SINCE_FIRST_GIFT      0.002662             0.988033   0.201485
# FILE_CARD_GIFT              -0.010457             0.744619   0.166137
#
#                              MOR_HIT_RATE  MEDIAN_HOME_VALUE  \
# TARGET_D                         0.010374           0.086208
# MONTHS_SINCE_ORIGIN              0.081492          -0.047224
# DONOR_AGE                        0.098522          -0.001215
# MOR_HIT_RATE                     1.000000           0.012690
# MEDIAN_HOME_VALUE                0.012690           1.000000
# MEDIAN_HOUSEHOLD_INCOME          0.041559           0.678902
# PCT_OWNER_OCCUPIED               0.014433           0.034832
# PER_CAPITA_INCOME                0.047631           0.729814
# FREQUENCY_STATUS_97NK           -0.002413          -0.056695
# RECENT_RESPONSE_PROP            -0.023233          -0.047137
# RECENT_AVG_GIFT_AMT              0.003006           0.116168
# RECENT_CARD_RESPONSE_PROP       -0.017916          -0.008996
# RECENT_AVG_CARD_GIFT_AMT         0.011849           0.083985
# RECENT_RESPONSE_COUNT           -0.004076          -0.056930
# RECENT_CARD_RESPONSE_COUNT      -0.004701          -0.026534
# MONTHS_SINCE_LAST_PROM_RESP     -0.003991           0.004329
# LIFETIME_CARD_PROM               0.075181          -0.032191
# LIFETIME_PROM                    0.081204          -0.019279
# LIFETIME_GIFT_AMOUNT             0.049564           0.026264
# LIFETIME_GIFT_COUNT              0.048885          -0.061424
# LIFETIME_AVG_GIFT_AMT           -0.008841           0.124098
# LIFETIME_GIFT_RANGE              0.020386           0.037737
# LIFETIME_MAX_GIFT_AMT            0.005460           0.080810
# LIFETIME_MIN_GIFT_AMT           -0.029134           0.093344
# LAST_GIFT_AMT                   -0.002715           0.107612
# CARD_PROM_12                     0.032729           0.017826
# NUMBER_PROM_12                   0.051570           0.027617
# MONTHS_SINCE_LAST_GIFT          -0.029942          -0.010213
# MONTHS_SINCE_FIRST_GIFT          0.082756          -0.045561
# FILE_CARD_GIFT                   0.052500          -0.054423
#
#                              MEDIAN_HOUSEHOLD_INCOME  PCT_OWNER_OCCUPIED  \
# TARGET_D                                    0.070328            0.008458
# MONTHS_SINCE_ORIGIN                        -0.036137            0.036576
# DONOR_AGE                                  -0.057405           -0.018317
# MOR_HIT_RATE                                0.041559            0.014433
# MEDIAN_HOME_VALUE                           0.678902            0.034832
# MEDIAN_HOUSEHOLD_INCOME                     1.000000            0.441422
# PCT_OWNER_OCCUPIED                          0.441422            1.000000
# PER_CAPITA_INCOME                           0.811189            0.208398
# FREQUENCY_STATUS_97NK                      -0.052706            0.007333
# RECENT_RESPONSE_PROP                       -0.050043           -0.010790
# RECENT_AVG_GIFT_AMT                         0.101187           -0.003915
# RECENT_CARD_RESPONSE_PROP                  -0.014326           -0.014322
# RECENT_AVG_CARD_GIFT_AMT                    0.071251           -0.006081
# RECENT_RESPONSE_COUNT                      -0.050304            0.013050
# RECENT_CARD_RESPONSE_COUNT                 -0.021206            0.008061
# MONTHS_SINCE_LAST_PROM_RESP                 0.016534            0.001125
# LIFETIME_CARD_PROM                         -0.023326            0.036801
# LIFETIME_PROM                              -0.014297            0.034609
# LIFETIME_GIFT_AMOUNT                        0.019201            0.011851
# LIFETIME_GIFT_COUNT                        -0.065548            0.013819
# LIFETIME_AVG_GIFT_AMT                       0.106664           -0.014918
# LIFETIME_GIFT_RANGE                         0.039981            0.014371
# LIFETIME_MAX_GIFT_AMT                       0.073700           -0.000938
# LIFETIME_MIN_GIFT_AMT                       0.074076           -0.030508
# LAST_GIFT_AMT                               0.093090           -0.003483
# CARD_PROM_12                                0.016495            0.012079
# NUMBER_PROM_12                              0.018085            0.005953
# MONTHS_SINCE_LAST_GIFT                      0.007816            0.010631
# MONTHS_SINCE_FIRST_GIFT                    -0.035408            0.037168
# FILE_CARD_GIFT                             -0.050887            0.024006
#
#                              PER_CAPITA_INCOME  FREQUENCY_STATUS_97NK  \
# TARGET_D                              0.081913              -0.026535
# MONTHS_SINCE_ORIGIN                  -0.025415               0.057012
# DONOR_AGE                             0.006141               0.040411
# MOR_HIT_RATE                          0.047631              -0.002413
# MEDIAN_HOME_VALUE                     0.729814              -0.056695
# MEDIAN_HOUSEHOLD_INCOME               0.811189              -0.052706
# PCT_OWNER_OCCUPIED                    0.208398               0.007333
# PER_CAPITA_INCOME                     1.000000              -0.052802
# FREQUENCY_STATUS_97NK                -0.052802               1.000000
# RECENT_RESPONSE_PROP                 -0.045530               0.709953
# RECENT_AVG_GIFT_AMT                   0.119308              -0.409849
# RECENT_CARD_RESPONSE_PROP            -0.003516               0.482205
# RECENT_AVG_CARD_GIFT_AMT              0.090131              -0.128558
# RECENT_RESPONSE_COUNT                -0.052551               0.771330
# RECENT_CARD_RESPONSE_COUNT           -0.018619               0.630948
# MONTHS_SINCE_LAST_PROM_RESP           0.007610              -0.345087
# LIFETIME_CARD_PROM                   -0.016097               0.124192
# LIFETIME_PROM                        -0.002992               0.115048
# LIFETIME_GIFT_AMOUNT                  0.035406               0.085369
# LIFETIME_GIFT_COUNT                  -0.054932               0.348083
# LIFETIME_AVG_GIFT_AMT                 0.125560              -0.371030
# LIFETIME_GIFT_RANGE                   0.052912              -0.074510
# LIFETIME_MAX_GIFT_AMT                 0.090494              -0.231957
# LIFETIME_MIN_GIFT_AMT                 0.083364              -0.335118
# LAST_GIFT_AMT                         0.112016              -0.383160
# CARD_PROM_12                          0.017295               0.279296
# NUMBER_PROM_12                        0.030060               0.157143
# MONTHS_SINCE_LAST_GIFT               -0.007869              -0.298834
# MONTHS_SINCE_FIRST_GIFT              -0.024838               0.061202
# FILE_CARD_GIFT                       -0.041447               0.321276
#
#                              RECENT_RESPONSE_PROP  RECENT_AVG_GIFT_AMT  \
# TARGET_D                                -0.025106             0.158420
# MONTHS_SINCE_ORIGIN                     -0.111962            -0.088864
# DONOR_AGE                                0.020803            -0.036175
# MOR_HIT_RATE                            -0.023233             0.003006
# MEDIAN_HOME_VALUE                       -0.047137             0.116168
# MEDIAN_HOUSEHOLD_INCOME                 -0.050043             0.101187
# PCT_OWNER_OCCUPIED                      -0.010790            -0.003915
# PER_CAPITA_INCOME                       -0.045530             0.119308
# FREQUENCY_STATUS_97NK                    0.709953            -0.409849
# RECENT_RESPONSE_PROP                     1.000000            -0.357041
# RECENT_AVG_GIFT_AMT                     -0.357041             1.000000
# RECENT_CARD_RESPONSE_PROP                0.743859            -0.252247
# RECENT_AVG_CARD_GIFT_AMT                -0.074848             0.613293
# RECENT_RESPONSE_COUNT                    0.798868            -0.386331
# RECENT_CARD_RESPONSE_COUNT               0.710642            -0.314923
# MONTHS_SINCE_LAST_PROM_RESP             -0.373680             0.149881
# LIFETIME_CARD_PROM                      -0.072734            -0.066907
# LIFETIME_PROM                           -0.080687            -0.033759
# LIFETIME_GIFT_AMOUNT                     0.033797             0.326236
# LIFETIME_GIFT_COUNT                      0.299870            -0.240979
# LIFETIME_AVG_GIFT_AMT                   -0.253907             0.887790
# LIFETIME_GIFT_RANGE                     -0.152647             0.487348
# LIFETIME_MAX_GIFT_AMT                   -0.211312             0.736879
# LIFETIME_MIN_GIFT_AMT                   -0.136855             0.566563
# LAST_GIFT_AMT                           -0.313647             0.882308
# CARD_PROM_12                             0.083923             0.006412
# NUMBER_PROM_12                           0.056166             0.078634
# MONTHS_SINCE_LAST_GIFT                  -0.285538             0.093789
# MONTHS_SINCE_FIRST_GIFT                 -0.109651            -0.091578
# FILE_CARD_GIFT                           0.297455            -0.245062
#
#                              RECENT_CARD_RESPONSE_PROP  \
# TARGET_D                                     -0.007350
# MONTHS_SINCE_ORIGIN                          -0.204587
# DONOR_AGE                                    -0.020718
# MOR_HIT_RATE                                 -0.017916
# MEDIAN_HOME_VALUE                            -0.008996
# MEDIAN_HOUSEHOLD_INCOME                      -0.014326
# PCT_OWNER_OCCUPIED                           -0.014322
# PER_CAPITA_INCOME                            -0.003516
# FREQUENCY_STATUS_97NK                         0.482205
# RECENT_RESPONSE_PROP                          0.743859
# RECENT_AVG_GIFT_AMT                          -0.252247
# RECENT_CARD_RESPONSE_PROP                     1.000000
# RECENT_AVG_CARD_GIFT_AMT                      0.202074
# RECENT_RESPONSE_COUNT                         0.527417
# RECENT_CARD_RESPONSE_COUNT                    0.781374
# MONTHS_SINCE_LAST_PROM_RESP                  -0.248802
# LIFETIME_CARD_PROM                           -0.178980
# LIFETIME_PROM                                -0.176696
# LIFETIME_GIFT_AMOUNT                         -0.039354
# LIFETIME_GIFT_COUNT                           0.145873
# LIFETIME_AVG_GIFT_AMT                        -0.134042
# LIFETIME_GIFT_RANGE                          -0.174849
# LIFETIME_MAX_GIFT_AMT                        -0.161012
# LIFETIME_MIN_GIFT_AMT                         0.012034
# LAST_GIFT_AMT                                -0.229752
# CARD_PROM_12                                  0.006917
# NUMBER_PROM_12                                0.014432
# MONTHS_SINCE_LAST_GIFT                       -0.187168
# MONTHS_SINCE_FIRST_GIFT                      -0.205475
# FILE_CARD_GIFT                                0.252548
#
#                              RECENT_AVG_CARD_GIFT_AMT  RECENT_RESPONSE_COUNT  \
# TARGET_D                                     0.113677              -0.022653
# MONTHS_SINCE_ORIGIN                         -0.106095               0.171037
# DONOR_AGE                                   -0.024047               0.052733
# MOR_HIT_RATE                                 0.011849              -0.004076
# MEDIAN_HOME_VALUE                            0.083985              -0.056930
# MEDIAN_HOUSEHOLD_INCOME                      0.071251              -0.050304
# PCT_OWNER_OCCUPIED                          -0.006081               0.013050
# PER_CAPITA_INCOME                            0.090131              -0.052551
# FREQUENCY_STATUS_97NK                       -0.128558               0.771330
# RECENT_RESPONSE_PROP                        -0.074848               0.798868
# RECENT_AVG_GIFT_AMT                          0.613293              -0.386331
# RECENT_CARD_RESPONSE_PROP                    0.202074               0.527417
# RECENT_AVG_CARD_GIFT_AMT                     1.000000              -0.093237
# RECENT_RESPONSE_COUNT                       -0.093237               1.000000
# RECENT_CARD_RESPONSE_COUNT                   0.101714               0.833676
# MONTHS_SINCE_LAST_PROM_RESP                  0.051339              -0.262624
# LIFETIME_CARD_PROM                          -0.051687               0.313042
# LIFETIME_PROM                               -0.030263               0.288931
# LIFETIME_GIFT_AMOUNT                         0.282919               0.242461
# LIFETIME_GIFT_COUNT                         -0.106453               0.544128
# LIFETIME_AVG_GIFT_AMT                        0.593425              -0.360482
# LIFETIME_GIFT_RANGE                          0.335509              -0.022243
# LIFETIME_MAX_GIFT_AMT                        0.495664              -0.197159
# LIFETIME_MIN_GIFT_AMT                        0.365817              -0.366485
# LAST_GIFT_AMT                                0.534118              -0.332223
# CARD_PROM_12                                 0.075797               0.349762
# NUMBER_PROM_12                               0.102389               0.211512
# MONTHS_SINCE_LAST_GIFT                       0.018154              -0.222640
# MONTHS_SINCE_FIRST_GIFT                     -0.106317               0.181154
# FILE_CARD_GIFT                              -0.052327               0.518151
#
#                              RECENT_CARD_RESPONSE_COUNT  \
# TARGET_D                                      -0.004611
# MONTHS_SINCE_ORIGIN                            0.087182
# DONOR_AGE                                      0.025876
# MOR_HIT_RATE                                  -0.004701
# MEDIAN_HOME_VALUE                             -0.026534
# MEDIAN_HOUSEHOLD_INCOME                       -0.021206
# PCT_OWNER_OCCUPIED                             0.008061
# PER_CAPITA_INCOME                             -0.018619
# FREQUENCY_STATUS_97NK                          0.630948
# RECENT_RESPONSE_PROP                           0.710642
# RECENT_AVG_GIFT_AMT                           -0.314923
# RECENT_CARD_RESPONSE_PROP                      0.781374
# RECENT_AVG_CARD_GIFT_AMT                       0.101714
# RECENT_RESPONSE_COUNT                          0.833676
# RECENT_CARD_RESPONSE_COUNT                     1.000000
# MONTHS_SINCE_LAST_PROM_RESP                   -0.167878
# LIFETIME_CARD_PROM                             0.214613
# LIFETIME_PROM                                  0.197061
# LIFETIME_GIFT_AMOUNT                           0.198761
# LIFETIME_GIFT_COUNT                            0.452243
# LIFETIME_AVG_GIFT_AMT                         -0.270459
# LIFETIME_GIFT_RANGE                           -0.042431
# LIFETIME_MAX_GIFT_AMT                         -0.161076
# LIFETIME_MIN_GIFT_AMT                         -0.251210
# LAST_GIFT_AMT                                 -0.275556
# CARD_PROM_12                                   0.269207
# NUMBER_PROM_12                                 0.167150
# MONTHS_SINCE_LAST_GIFT                        -0.152319
# MONTHS_SINCE_FIRST_GIFT                        0.095240
# FILE_CARD_GIFT                                 0.534581
#
#                              MONTHS_SINCE_LAST_PROM_RESP  LIFETIME_CARD_PROM  \
# TARGET_D                                       -0.003884            0.012447
# MONTHS_SINCE_ORIGIN                             0.048191            0.912970
# DONOR_AGE                                      -0.022459            0.182720
# MOR_HIT_RATE                                   -0.003991            0.075181
# MEDIAN_HOME_VALUE                               0.004329           -0.032191
# MEDIAN_HOUSEHOLD_INCOME                         0.016534           -0.023326
# PCT_OWNER_OCCUPIED                              0.001125            0.036801
# PER_CAPITA_INCOME                               0.007610           -0.016097
# FREQUENCY_STATUS_97NK                          -0.345087            0.124192
# RECENT_RESPONSE_PROP                           -0.373680           -0.072734
# RECENT_AVG_GIFT_AMT                             0.149881           -0.066907
# RECENT_CARD_RESPONSE_PROP                      -0.248802           -0.178980
# RECENT_AVG_CARD_GIFT_AMT                        0.051339           -0.051687
# RECENT_RESPONSE_COUNT                          -0.262624            0.313042
# RECENT_CARD_RESPONSE_COUNT                     -0.167878            0.214613
# MONTHS_SINCE_LAST_PROM_RESP                     1.000000            0.043342
# LIFETIME_CARD_PROM                              0.043342            1.000000
# LIFETIME_PROM                                   0.032820            0.951909
# LIFETIME_GIFT_AMOUNT                            0.043548            0.614567
# LIFETIME_GIFT_COUNT                            -0.057682            0.776470
# LIFETIME_AVG_GIFT_AMT                           0.118087           -0.247696
# LIFETIME_GIFT_RANGE                             0.083991            0.262852
# LIFETIME_MAX_GIFT_AMT                           0.105648            0.024676
# LIFETIME_MIN_GIFT_AMT                           0.053174           -0.470886
# LAST_GIFT_AMT                                   0.130088           -0.081612
# CARD_PROM_12                                   -0.136458            0.396895
# NUMBER_PROM_12                                 -0.155281            0.327467
# MONTHS_SINCE_LAST_GIFT                          0.683160           -0.076996
# MONTHS_SINCE_FIRST_GIFT                         0.048901            0.917366
# FILE_CARD_GIFT                                 -0.056375            0.777901
#
#                              LIFETIME_PROM  LIFETIME_GIFT_AMOUNT  \
# TARGET_D                          0.028323              0.108921
# MONTHS_SINCE_ORIGIN               0.864536              0.517699
# DONOR_AGE                         0.185501              0.117053
# MOR_HIT_RATE                      0.081204              0.049564
# MEDIAN_HOME_VALUE                -0.019279              0.026264
# MEDIAN_HOUSEHOLD_INCOME          -0.014297              0.019201
# PCT_OWNER_OCCUPIED                0.034609              0.011851
# PER_CAPITA_INCOME                -0.002992              0.035406
# FREQUENCY_STATUS_97NK             0.115048              0.085369
# RECENT_RESPONSE_PROP             -0.080687              0.033797
# RECENT_AVG_GIFT_AMT              -0.033759              0.326236
# RECENT_CARD_RESPONSE_PROP        -0.176696             -0.039354
# RECENT_AVG_CARD_GIFT_AMT         -0.030263              0.282919
# RECENT_RESPONSE_COUNT             0.288931              0.242461
# RECENT_CARD_RESPONSE_COUNT        0.197061              0.198761
# MONTHS_SINCE_LAST_PROM_RESP       0.032820              0.043548
# LIFETIME_CARD_PROM                0.951909              0.614567
# LIFETIME_PROM                     1.000000              0.681654
# LIFETIME_GIFT_AMOUNT              0.681654              1.000000
# LIFETIME_GIFT_COUNT               0.794310              0.658165
# LIFETIME_AVG_GIFT_AMT            -0.201287              0.236447
# LIFETIME_GIFT_RANGE               0.304691              0.561631
# LIFETIME_MAX_GIFT_AMT             0.076675              0.470077
# LIFETIME_MIN_GIFT_AMT            -0.445706             -0.136784
# LAST_GIFT_AMT                    -0.052118              0.272917
# CARD_PROM_12                      0.401027              0.262400
# NUMBER_PROM_12                    0.503823              0.384483
# MONTHS_SINCE_LAST_GIFT           -0.159280             -0.129993
# MONTHS_SINCE_FIRST_GIFT           0.874210              0.532543
# FILE_CARD_GIFT                    0.749481              0.566838
#
#                              LIFETIME_GIFT_COUNT  LIFETIME_AVG_GIFT_AMT  \
# TARGET_D                               -0.011126               0.155431
# MONTHS_SINCE_ORIGIN                     0.717176              -0.281578
# DONOR_AGE                               0.170892              -0.066350
# MOR_HIT_RATE                            0.048885              -0.008841
# MEDIAN_HOME_VALUE                      -0.061424               0.124098
# MEDIAN_HOUSEHOLD_INCOME                -0.065548               0.106664
# PCT_OWNER_OCCUPIED                      0.013819              -0.014918
# PER_CAPITA_INCOME                      -0.054932               0.125560
# FREQUENCY_STATUS_97NK                   0.348083              -0.371030
# RECENT_RESPONSE_PROP                    0.299870              -0.253907
# RECENT_AVG_GIFT_AMT                    -0.240979               0.887790
# RECENT_CARD_RESPONSE_PROP               0.145873              -0.134042
# RECENT_AVG_CARD_GIFT_AMT               -0.106453               0.593425
# RECENT_RESPONSE_COUNT                   0.544128              -0.360482
# RECENT_CARD_RESPONSE_COUNT              0.452243              -0.270459
# MONTHS_SINCE_LAST_PROM_RESP            -0.057682               0.118087
# LIFETIME_CARD_PROM                      0.776470              -0.247696
# LIFETIME_PROM                           0.794310              -0.201287
# LIFETIME_GIFT_AMOUNT                    0.658165               0.236447
# LIFETIME_GIFT_COUNT                     1.000000              -0.340690
# LIFETIME_AVG_GIFT_AMT                  -0.340690               1.000000
# LIFETIME_GIFT_RANGE                     0.147216               0.357536
# LIFETIME_MAX_GIFT_AMT                  -0.069796               0.716623
# LIFETIME_MIN_GIFT_AMT                  -0.437902               0.782306
# LAST_GIFT_AMT                          -0.235776               0.801788
# CARD_PROM_12                            0.229916              -0.029440
# NUMBER_PROM_12                          0.295036               0.061187
# MONTHS_SINCE_LAST_GIFT                 -0.170061               0.070252
# MONTHS_SINCE_FIRST_GIFT                 0.730905              -0.285706
# FILE_CARD_GIFT                          0.919366              -0.345639
#
#                              LIFETIME_GIFT_RANGE  LIFETIME_MAX_GIFT_AMT  \
# TARGET_D                                0.114607               0.145331
# MONTHS_SINCE_ORIGIN                     0.212928              -0.017875
# DONOR_AGE                               0.028041              -0.019377
# MOR_HIT_RATE                            0.020386               0.005460
# MEDIAN_HOME_VALUE                       0.037737               0.080810
# MEDIAN_HOUSEHOLD_INCOME                 0.039981               0.073700
# PCT_OWNER_OCCUPIED                      0.014371              -0.000938
# PER_CAPITA_INCOME                       0.052912               0.090494
# FREQUENCY_STATUS_97NK                  -0.074510              -0.231957
# RECENT_RESPONSE_PROP                   -0.152647              -0.211312
# RECENT_AVG_GIFT_AMT                     0.487348               0.736879
# RECENT_CARD_RESPONSE_PROP              -0.174849              -0.161012
# RECENT_AVG_CARD_GIFT_AMT                0.335509               0.495664
# RECENT_RESPONSE_COUNT                  -0.022243              -0.197159
# RECENT_CARD_RESPONSE_COUNT             -0.042431              -0.161076
# MONTHS_SINCE_LAST_PROM_RESP             0.083991               0.105648
# LIFETIME_CARD_PROM                      0.262852               0.024676
# LIFETIME_PROM                           0.304691               0.076675
# LIFETIME_GIFT_AMOUNT                    0.561631               0.470077
# LIFETIME_GIFT_COUNT                     0.147216              -0.069796
# LIFETIME_AVG_GIFT_AMT                   0.357536               0.716623
# LIFETIME_GIFT_RANGE                     1.000000               0.880309
# LIFETIME_MAX_GIFT_AMT                   0.880309               1.000000
# LIFETIME_MIN_GIFT_AMT                  -0.153307               0.333836
# LAST_GIFT_AMT                           0.504345               0.719387
# CARD_PROM_12                            0.166820               0.075198
# NUMBER_PROM_12                          0.224144               0.165423
# MONTHS_SINCE_LAST_GIFT                 -0.035039               0.012432
# MONTHS_SINCE_FIRST_GIFT                 0.218533              -0.016973
# FILE_CARD_GIFT                          0.103458              -0.105408
#
#                              LIFETIME_MIN_GIFT_AMT  LAST_GIFT_AMT  \
# TARGET_D                                  0.075000       0.172161
# MONTHS_SINCE_ORIGIN                      -0.460319      -0.107102
# DONOR_AGE                                -0.096081      -0.041094
# MOR_HIT_RATE                             -0.029134      -0.002715
# MEDIAN_HOME_VALUE                         0.093344       0.107612
# MEDIAN_HOUSEHOLD_INCOME                   0.074076       0.093090
# PCT_OWNER_OCCUPIED                       -0.030508      -0.003483
# PER_CAPITA_INCOME                         0.083364       0.112016
# FREQUENCY_STATUS_97NK                    -0.335118      -0.383160
# RECENT_RESPONSE_PROP                     -0.136855      -0.313647
# RECENT_AVG_GIFT_AMT                       0.566563       0.882308
# RECENT_CARD_RESPONSE_PROP                 0.012034      -0.229752
# RECENT_AVG_CARD_GIFT_AMT                  0.365817       0.534118
# RECENT_RESPONSE_COUNT                    -0.366485      -0.332223
# RECENT_CARD_RESPONSE_COUNT               -0.251210      -0.275556
# MONTHS_SINCE_LAST_PROM_RESP               0.053174       0.130088
# LIFETIME_CARD_PROM                       -0.470886      -0.081612
# LIFETIME_PROM                            -0.445706      -0.052118
# LIFETIME_GIFT_AMOUNT                     -0.136784       0.272917
# LIFETIME_GIFT_COUNT                      -0.437902      -0.235776
# LIFETIME_AVG_GIFT_AMT                     0.782306       0.801788
# LIFETIME_GIFT_RANGE                      -0.153307       0.504345
# LIFETIME_MAX_GIFT_AMT                     0.333836       0.719387
# LIFETIME_MIN_GIFT_AMT                     1.000000       0.496354
# LAST_GIFT_AMT                             0.496354       1.000000
# CARD_PROM_12                             -0.174832       0.018489
# NUMBER_PROM_12                           -0.100795       0.068093
# MONTHS_SINCE_LAST_GIFT                    0.095519       0.101232
# MONTHS_SINCE_FIRST_GIFT                  -0.469579      -0.108881
# FILE_CARD_GIFT                           -0.425135      -0.240262
#
#                              CARD_PROM_12  NUMBER_PROM_12  \
# TARGET_D                         0.034278        0.056681
# MONTHS_SINCE_ORIGIN              0.125605        0.143328
# DONOR_AGE                        0.037407        0.075436
# MOR_HIT_RATE                     0.032729        0.051570
# MEDIAN_HOME_VALUE                0.017826        0.027617
# MEDIAN_HOUSEHOLD_INCOME          0.016495        0.018085
# PCT_OWNER_OCCUPIED               0.012079        0.005953
# PER_CAPITA_INCOME                0.017295        0.030060
# FREQUENCY_STATUS_97NK            0.279296        0.157143
# RECENT_RESPONSE_PROP             0.083923        0.056166
# RECENT_AVG_GIFT_AMT              0.006412        0.078634
# RECENT_CARD_RESPONSE_PROP        0.006917        0.014432
# RECENT_AVG_CARD_GIFT_AMT         0.075797        0.102389
# RECENT_RESPONSE_COUNT            0.349762        0.211512
# RECENT_CARD_RESPONSE_COUNT       0.269207        0.167150
# MONTHS_SINCE_LAST_PROM_RESP     -0.136458       -0.155281
# LIFETIME_CARD_PROM               0.396895        0.327467
# LIFETIME_PROM                    0.401027        0.503823
# LIFETIME_GIFT_AMOUNT             0.262400        0.384483
# LIFETIME_GIFT_COUNT              0.229916        0.295036
# LIFETIME_AVG_GIFT_AMT           -0.029440        0.061187
# LIFETIME_GIFT_RANGE              0.166820        0.224144
# LIFETIME_MAX_GIFT_AMT            0.075198        0.165423
# LIFETIME_MIN_GIFT_AMT           -0.174832       -0.100795
# LAST_GIFT_AMT                    0.018489        0.068093
# CARD_PROM_12                     1.000000        0.663036
# NUMBER_PROM_12                   0.663036        1.000000
# MONTHS_SINCE_LAST_GIFT          -0.311342       -0.508607
# MONTHS_SINCE_FIRST_GIFT          0.137826        0.154731
# FILE_CARD_GIFT                   0.171581        0.180283
#
#                              MONTHS_SINCE_LAST_GIFT  MONTHS_SINCE_FIRST_GIFT  \
# TARGET_D                                  -0.027665                 0.002662
# MONTHS_SINCE_ORIGIN                       -0.021839                 0.988033
# DONOR_AGE                                 -0.067942                 0.201485
# MOR_HIT_RATE                              -0.029942                 0.082756
# MEDIAN_HOME_VALUE                         -0.010213                -0.045561
# MEDIAN_HOUSEHOLD_INCOME                    0.007816                -0.035408
# PCT_OWNER_OCCUPIED                         0.010631                 0.037168
# PER_CAPITA_INCOME                         -0.007869                -0.024838
# FREQUENCY_STATUS_97NK                     -0.298834                 0.061202
# RECENT_RESPONSE_PROP                      -0.285538                -0.109651
# RECENT_AVG_GIFT_AMT                        0.093789                -0.091578
# RECENT_CARD_RESPONSE_PROP                 -0.187168                -0.205475
# RECENT_AVG_CARD_GIFT_AMT                   0.018154                -0.106317
# RECENT_RESPONSE_COUNT                     -0.222640                 0.181154
# RECENT_CARD_RESPONSE_COUNT                -0.152319                 0.095240
# MONTHS_SINCE_LAST_PROM_RESP                0.683160                 0.048901
# LIFETIME_CARD_PROM                        -0.076996                 0.917366
# LIFETIME_PROM                             -0.159280                 0.874210
# LIFETIME_GIFT_AMOUNT                      -0.129993                 0.532543
# LIFETIME_GIFT_COUNT                       -0.170061                 0.730905
# LIFETIME_AVG_GIFT_AMT                      0.070252                -0.285706
# LIFETIME_GIFT_RANGE                       -0.035039                 0.218533
# LIFETIME_MAX_GIFT_AMT                      0.012432                -0.016973
# LIFETIME_MIN_GIFT_AMT                      0.095519                -0.469579
# LAST_GIFT_AMT                              0.101232                -0.108881
# CARD_PROM_12                              -0.311342                 0.137826
# NUMBER_PROM_12                            -0.508607                 0.154731
# MONTHS_SINCE_LAST_GIFT                     1.000000                -0.026132
# MONTHS_SINCE_FIRST_GIFT                   -0.026132                 1.000000
# FILE_CARD_GIFT                            -0.107524                 0.752263
#
#                              FILE_CARD_GIFT
# TARGET_D                          -0.010457
# MONTHS_SINCE_ORIGIN                0.744619
# DONOR_AGE                          0.166137
# MOR_HIT_RATE                       0.052500
# MEDIAN_HOME_VALUE                 -0.054423
# MEDIAN_HOUSEHOLD_INCOME           -0.050887
# PCT_OWNER_OCCUPIED                 0.024006
# PER_CAPITA_INCOME                 -0.041447
# FREQUENCY_STATUS_97NK              0.321276
# RECENT_RESPONSE_PROP               0.297455
# RECENT_AVG_GIFT_AMT               -0.245062
# RECENT_CARD_RESPONSE_PROP          0.252548
# RECENT_AVG_CARD_GIFT_AMT          -0.052327
# RECENT_RESPONSE_COUNT              0.518151
# RECENT_CARD_RESPONSE_COUNT         0.534581
# MONTHS_SINCE_LAST_PROM_RESP       -0.056375
# LIFETIME_CARD_PROM                 0.777901
# LIFETIME_PROM                      0.749481
# LIFETIME_GIFT_AMOUNT               0.566838
# LIFETIME_GIFT_COUNT                0.919366
# LIFETIME_AVG_GIFT_AMT             -0.345639
# LIFETIME_GIFT_RANGE                0.103458
# LIFETIME_MAX_GIFT_AMT             -0.105408
# LIFETIME_MIN_GIFT_AMT             -0.425135
# LAST_GIFT_AMT                     -0.240262
# CARD_PROM_12                       0.171581
# NUMBER_PROM_12                     0.180283
# MONTHS_SINCE_LAST_GIFT            -0.107524
# MONTHS_SINCE_FIRST_GIFT            0.752263
# FILE_CARD_GIFT                     1.000000

# %%
plt.figure(figsize=(30,20))
sns.heatmap(donors.corr(), vmin=-1, vmax=1, cmap="coolwarm", annot=True)
plt.show()

# %% [markdown]
# After a first look at the correlation matrix, we can see that there are no numerical variables with a high correlation with the target variable TARGET_D. There are also some really high correlations between some of the other features, which might be a problem:
# + `MONTHS_SINCE_FIRST_GIFT`, `FILE_CARD_GIFT`, the 2 `RECENT_RESPONSE` variables and the `LIFETIME` variables all show high correlation with other features (>0.8).

# %%
donors["TARGET_B"].dtype.name != 'category'
# Out:
# False

# %%
numVars = []
for col in donors.columns:
    if donors[col].dtype.name != "category":
        numVars.append(col)

numVars
# Out:
# ['TARGET_D',
#  'MONTHS_SINCE_ORIGIN',
#  'DONOR_AGE',
#  'MOR_HIT_RATE',
#  'MEDIAN_HOME_VALUE',
#  'MEDIAN_HOUSEHOLD_INCOME',
#  'PCT_OWNER_OCCUPIED',
#  'PER_CAPITA_INCOME',
#  'FREQUENCY_STATUS_97NK',
#  'RECENT_RESPONSE_PROP',
#  'RECENT_AVG_GIFT_AMT',
#  'RECENT_CARD_RESPONSE_PROP',
#  'RECENT_AVG_CARD_GIFT_AMT',
#  'RECENT_RESPONSE_COUNT',
#  'RECENT_CARD_RESPONSE_COUNT',
#  'MONTHS_SINCE_LAST_PROM_RESP',
#  'LIFETIME_CARD_PROM',
#  'LIFETIME_PROM',
#  'LIFETIME_GIFT_AMOUNT',
#  'LIFETIME_GIFT_COUNT',
#  'LIFETIME_AVG_GIFT_AMT',
#  'LIFETIME_GIFT_RANGE',
#  'LIFETIME_MAX_GIFT_AMT',
#  'LIFETIME_MIN_GIFT_AMT',
#  'LAST_GIFT_AMT',
#  'CARD_PROM_12',
#  'NUMBER_PROM_12',
#  'MONTHS_SINCE_LAST_GIFT',
#  'MONTHS_SINCE_FIRST_GIFT',
#  'FILE_CARD_GIFT']

# %%
catVars = []
for col in donors.columns:
    if donors[col].dtype.name == "category":
        catVars.append(col)

catVars
# Out:
# ['TARGET_B',
#  'IN_HOUSE',
#  'URBANICITY',
#  'SES',
#  'CLUSTER_CODE',
#  'HOME_OWNER',
#  'DONOR_GENDER',
#  'PUBLISHED_PHONE',
#  'OVERLAY_SOURCE',
#  'PEP_STAR',
#  'RECENT_STAR_STATUS',
#  'RECENCY_STATUS_96NK',
#  'DONATION_TYPE']

# %%
sns.countplot(x=donors['TARGET_B'])
plt.show()

# %% [markdown]
# There are a lot more 0's in TARGET_B then 1's. This might cause some problems because the groups are too unbalanced.

# %%
sns.countplot(x=donors["DONATION_TYPE"])
plt.show()

# %% [markdown]
# We can see the same problem in DONATION_TYPE, group E has a lot more members than the others due to the fact that all the donors that didn't donate (`TARGET_B` = 0) are in this group. We can arrange for `DONATION_TYPE` group E to not include `TARGET_D` = 0 so we can achieve group balance.

# %%
activeIndex = []
for i in donors.index:
    if donors["TARGET_D"][i] != 0:
        activeIndex.append(i)
        
len(activeIndex)
# Out:
# 4665

# %%
activeDonors = donors.loc[activeIndex]

# %%
sns.countplot(x=activeDonors["DONATION_TYPE"])
plt.show()

# %% [markdown]
# Looking only at people who actually donated, we can see that the groups are now more balanced, even though group "A" - the biggest donors - are at a clear minority.

# %%
sns.countplot(x=donors['URBANICITY'])
plt.show()
# Out:
# <AxesSubplot:xlabel='URBANICITY', ylabel='count'>

# %%
sns.countplot(x=donors['RECENCY_STATUS_96NK'])
plt.show()
# Out:
# <AxesSubplot:xlabel='RECENCY_STATUS_96NK', ylabel='count'>

# %% [markdown]
# The groups are too unbalanced, with active ("A") donors being more than half of all donors. Active and star ("S") donors make about 80% of all donors.

# %%
sns.countplot(x=donors['SES'])
plt.show()

# %%
sns.countplot(x=donors['CLUSTER_CODE'])
plt.show()

# %% [markdown]
# There are 54(!) values for this variable. From the dataset description we see that `CLUSTER_CODE` reflects socioeconomic status, urbanicity, ethnicity, and other demographic characteristics. We already have all of this information in other features so this can be considered redundant data. We will also have to create new clusters from this data and if we use this it will obviously impact the new clusters. We can drop this feature and not lose any information.

# %%
donors = donors.drop("CLUSTER_CODE", axis=1)

# %%
sns.countplot(x=donors['HOME_OWNER'])
plt.show()

# %%
sns.countplot(x=donors['DONOR_GENDER'])
plt.show()

# %%
sns.countplot(x=donors['PUBLISHED_PHONE'])
plt.show()

# %%
sns.countplot(x=donors['OVERLAY_SOURCE'])
plt.show()

# %%
sns.countplot(x=donors['PEP_STAR'])
plt.show()

# %%
sns.countplot(x=donors['RECENT_STAR_STATUS'])
plt.show()

# %% [markdown]
# There's a problem with this feature: from the dataset description we can see that `RECENT_STAR_STATUS` is supposed to be a binary variable. However, there are a lot of non 0 or 1 values. We can't really tell what these values are supposed to mean (number of months since star status, maybe?). We should probably just drop this feature as its values can't be used.

# %%
donors = donors.drop('RECENT_STAR_STATUS', axis=1)

# %%
donors['RECENT_STAR_STATUS']
# Out:
# 0        1
# 1        1
# 2        0
# 3        0
# 4        0
#         ..
# 18675    0
# 18676    1
# 18677    1
# 18678    0
# 18679    1
# Name: RECENT_STAR_STATUS, Length: 18680, dtype: category
# Categories (23, int64): [0, 1, 2, 3, ..., 19, 20, 21, 22]

# %% [markdown]
# ## Task 1 (Supervised Learning) - Predicting Donation and Donation Type
#
# In this task you should target 3 classification tasks:
# 1. **Predicting  Donation (binary classification task)**;
# 2. **Predicting Donation TYPE (multiclass classification)**; and
# 3. **Train specialized models for SES (socioeconomic classification)**.

# %% [markdown]
# **You should:**
#
# * Choose **one classifier in each category**: Tree models, Rule models, Linear models, Distance-based models, and Probabilistic models.
# * Use cross-validation to evaluate the results.
# * Present and discuss the results for different evaluation measures, present confusion matrices. Remember that not only overall results are important. Check what happens when learning to predict each class.
# * Describe the parameters used for each classifier and how their choice impacted or not the results.
# * Choose the best classifier and fundament you choice.
# * **Discuss critically your choices and the results!**

# %% [markdown]
# ## 1.1. Preprocessing Data for Classification

# %% [markdown]
# ## 1.2. Learning Classifiers

# %% [markdown]
# ...

# %% [markdown]
# ## 1.3. Classification - Results and Discussion

# %% [markdown]
# ...

# %% [markdown]
# ## Task 2 (Unsupervised Learning) - Characterizing Donors and Donation Type

# %% [markdown]
# In this task you should **use unsupervised learning algorithms and try to characterize donors (people who really did a donation) and their donation type**. You can use:
# * **Association rule mining** to find **associations between the features and the target Donation/DonationTYPE**.
# * **Clustering algorithms to find similar groups of donors**. Is it possible to find groups of donors with the same/similar DonationTYPE?
# * **Be creative and define your own unsupervised analysis!** What would it be interesting to find out ?

# %% [markdown]
# ## 2.1. Preprocessing Data for Association Rule Mining

# %% [markdown]
# ...

# %% [markdown]
# ## 2.2. Finding Associations

# %% [markdown]
# ...

# %% [markdown]
# ## 2.3 Association Rules - Results and Discussion

# %% [markdown]
# ...

# %% [markdown]
# ## 2.4. Preprocessing Data for Clustering

# %% [markdown]
# ...

# %% [markdown]
# ## 2.5. Finding Groups

# %% [markdown]
# ...

# %% [markdown]
# ## 2.6. Clustering - Results and Discussion

# %% [markdown]
# ...

# %% [markdown]
# ## 3. Final Comments and Conclusions

# %% [markdown]
# ...
